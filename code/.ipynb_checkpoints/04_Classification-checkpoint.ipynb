# %% [markdown]
# # Classification

# %% [markdown]
# ## Classifying Popularity Based on Audio Features and Genre

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, RandomForestRegressor, ExtraTreesRegressor, BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, VotingClassifier, GradientBoostingRegressor, AdaBoostRegressor, BaggingRegressor
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

import timeit

# %%
df = pd.read_csv('./data/dummified_genres.csv')
df
# Out:
#                 artist_name                                   track_name  \
# 0               Frank Ocean                                         Lost
# 1               David Bowie                   Five Years - 2012 Remaster
# 2            Kendrick Lamar                                  Money Trees
# 3      Electro Dark Project                                    Year 2012
# 4                Chief Keef                                    Love Sosa
# ...                     ...                                          ...
# 10059            Time Shard                Cosmic Carrot - 2022 Remaster
# 10060                Eminem                                     Darkness
# 10061       Eliseu Carvalho                             Krafty Days 2022
# 10062          Dustin Lynch  Thinking 'Bout You (feat. MacKenzie Porter)
# 10063            Time Shard           Voodoo Chronometer - 2022 Remaster
#
#                      track_id  popularity  danceability  energy  key  \
# 0      3GZD6HmiNUhxXYf8Gch723          85         0.913   0.603    8
# 1      1JIzFhI9Lt5FyslawmHCBi          59         0.460   0.326    7
# 2      2HbKqm4o0w5wEeEFXm2sD4          79         0.716   0.531    7
# 3      6AXz0oyVU4oXh9Tb98TXMd           0         0.501   0.687    0
# 4      01Lr5YepbgjXAWR9iOEyH1          80         0.772   0.413    0
# ...                       ...         ...           ...     ...  ...
# 10059  49u25ckAvC2vLaOFAKON5w           0         0.318   0.295    0
# 10060  48aI5wAluvSrq55EAR329i          53         0.608   0.623    2
# 10061  18IzyQBkLl4qMZj7Pkm4u3           0         0.807   0.580    1
# 10062  4wBjKhJx6JnGoNJfJs24pd          71         0.403   0.711    8
# 10063  0Y6jZQ942ExYc3DwkbjNUD           0         0.573   0.882   11
#
#        loudness  mode  speechiness  ...  genre_southern rock.1  \
# 0        -4.892     1       0.2260  ...                      0
# 1       -10.699     1       0.0417  ...                      0
# 2        -7.355     1       0.1220  ...                      0
# 3        -4.657     1       0.0494  ...                      0
# 4        -8.193     0       0.0890  ...                      0
# ...         ...   ...          ...  ...                    ...
# 10059   -16.727     1       0.0319  ...                      0
# 10060    -7.239     1       0.3070  ...                      0
# 10061   -12.847     1       0.0856  ...                      0
# 10062    -4.189     1       0.0569  ...                      0
# 10063    -9.497     0       0.0410  ...                      0
#
#        genre_symphonic rock.5  genre_vapor soul.3  genre_roots rock.9  \
# 0                           0                   0                   0
# 1                           0                   0                   0
# 2                           0                   0                   0
# 3                           0                   0                   0
# 4                           0                   0                   0
# ...                       ...                 ...                 ...
# 10059                       0                   0                   0
# 10060                       0                   0                   0
# 10061                       0                   0                   0
# 10062                       0                   0                   0
# 10063                       0                   0                   0
#
#        genre_soft rock.10  genre_symphonic rock.6  genre_southern rock.2  \
# 0                       0                       0                      0
# 1                       0                       0                      0
# 2                       0                       0                      0
# 3                       0                       0                      0
# 4                       0                       0                      0
# ...                   ...                     ...                    ...
# 10059                   0                       0                      0
# 10060                   0                       0                      0
# 10061                   0                       0                      0
# 10062                   0                       0                      0
# 10063                   0                       0                      0
#
#        genre_symphonic rock.7  genre_zolo.4  genre_swamp rock.1
# 0                           0             0                   0
# 1                           0             0                   0
# 2                           0             0                   0
# 3                           0             0                   0
# 4                           0             0                   0
# ...                       ...           ...                 ...
# 10059                       0             0                   0
# 10060                       0             0                   0
# 10061                       0             0                   0
# 10062                       0             0                   0
# 10063                       0             0                   0
#
# [10064 rows x 2588 columns]

# %%
dict_map = {range(0,41) : 0, range(41,100) : 1}
df['popularity_mapped'] = df['popularity'].apply(lambda x: next((v for k, v in dict_map.items() if x in k), 0))
df
# Out:
#                 artist_name                                   track_name  \
# 0               Frank Ocean                                         Lost
# 1               David Bowie                   Five Years - 2012 Remaster
# 2            Kendrick Lamar                                  Money Trees
# 3      Electro Dark Project                                    Year 2012
# 4                Chief Keef                                    Love Sosa
# ...                     ...                                          ...
# 10059            Time Shard                Cosmic Carrot - 2022 Remaster
# 10060                Eminem                                     Darkness
# 10061       Eliseu Carvalho                             Krafty Days 2022
# 10062          Dustin Lynch  Thinking 'Bout You (feat. MacKenzie Porter)
# 10063            Time Shard           Voodoo Chronometer - 2022 Remaster
#
#                      track_id  popularity  danceability  energy  key  \
# 0      3GZD6HmiNUhxXYf8Gch723          85         0.913   0.603    8
# 1      1JIzFhI9Lt5FyslawmHCBi          59         0.460   0.326    7
# 2      2HbKqm4o0w5wEeEFXm2sD4          79         0.716   0.531    7
# 3      6AXz0oyVU4oXh9Tb98TXMd           0         0.501   0.687    0
# 4      01Lr5YepbgjXAWR9iOEyH1          80         0.772   0.413    0
# ...                       ...         ...           ...     ...  ...
# 10059  49u25ckAvC2vLaOFAKON5w           0         0.318   0.295    0
# 10060  48aI5wAluvSrq55EAR329i          53         0.608   0.623    2
# 10061  18IzyQBkLl4qMZj7Pkm4u3           0         0.807   0.580    1
# 10062  4wBjKhJx6JnGoNJfJs24pd          71         0.403   0.711    8
# 10063  0Y6jZQ942ExYc3DwkbjNUD           0         0.573   0.882   11
#
#        loudness  mode  speechiness  ...  genre_symphonic rock.5  \
# 0        -4.892     1       0.2260  ...                       0
# 1       -10.699     1       0.0417  ...                       0
# 2        -7.355     1       0.1220  ...                       0
# 3        -4.657     1       0.0494  ...                       0
# 4        -8.193     0       0.0890  ...                       0
# ...         ...   ...          ...  ...                     ...
# 10059   -16.727     1       0.0319  ...                       0
# 10060    -7.239     1       0.3070  ...                       0
# 10061   -12.847     1       0.0856  ...                       0
# 10062    -4.189     1       0.0569  ...                       0
# 10063    -9.497     0       0.0410  ...                       0
#
#        genre_vapor soul.3  genre_roots rock.9  genre_soft rock.10  \
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       0                   0                   0
# 3                       0                   0                   0
# 4                       0                   0                   0
# ...                   ...                 ...                 ...
# 10059                   0                   0                   0
# 10060                   0                   0                   0
# 10061                   0                   0                   0
# 10062                   0                   0                   0
# 10063                   0                   0                   0
#
#        genre_symphonic rock.6  genre_southern rock.2  genre_symphonic rock.7  \
# 0                           0                      0                       0
# 1                           0                      0                       0
# 2                           0                      0                       0
# 3                           0                      0                       0
# 4                           0                      0                       0
# ...                       ...                    ...                     ...
# 10059                       0                      0                       0
# 10060                       0                      0                       0
# 10061                       0                      0                       0
# 10062                       0                      0                       0
# 10063                       0                      0                       0
#
#        genre_zolo.4  genre_swamp rock.1  popularity_mapped
# 0                 0                   0                  1
# 1                 0                   0                  1
# 2                 0                   0                  1
# 3                 0                   0                  0
# 4                 0                   0                  1
# ...             ...                 ...                ...
# 10059             0                   0                  0
# 10060             0                   0                  1
# 10061             0                   0                  0
# 10062             0                   0                  1
# 10063             0                   0                  0
#
# [10064 rows x 2589 columns]

# %%
X = df.drop(columns = ['artist_name', 'track_name', 'track_id', 'popularity', 'popularity_mapped'])
y = df['popularity_mapped']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, stratify = y)

# %%
logreg = LogisticRegression(max_iter = 10000)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
print(f'Train: {logreg.score(X_train, y_train)}')
print(f'Test: {logreg.score(X_test, y_test)}')
# Out:
# Train: 0.5416004239533652
# Test: 0.541335453100159

# %%
predslog = logreg.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predslog, 
                                        cmap = 'magma')
plt.title('Popularity Logistic Regression')

plt.tight_layout()
plt.savefig('./images/logreg_simple_cmatrix');

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)


print(f'Train: {rf.score(X_train, y_train)}')
print(f'Test: {rf.score(X_test, y_test)}')
# Out:
# Train: 0.9977477477477478
# Test: 0.8748012718600954

# %%
predsrf = rf.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predsrf, 
                                        cmap = 'magma')
plt.title('Popularity RandomForest')

plt.tight_layout()
plt.savefig('./images/rf_simple_cmatrix');

# %%
ada = AdaBoostClassifier()
ada.fit(X_train, y_train)


print(f'Train: {ada.score(X_train, y_train)}')
print(f'Test: {ada.score(X_test, y_test)}')
# Out:
# Train: 0.8434022257551669
# Test: 0.834658187599364

# %%
predsada = ada.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predsada, 
                                        cmap = 'magma')
plt.title('Popularity AdaBoost')

plt.tight_layout()
plt.savefig('./images/ada_simple_cmatrix');

# %%
gr = GradientBoostingClassifier()
gr.fit(X_train, y_train)

print(f'Train: {gr.score(X_train, y_train)}')
print(f'Test: {gr.score(X_test, y_test)}')
# Out:
# Train: 0.8501589825119237
# Test: 0.8302861685214626

# %%
predsgr = gr.predict(X_test)

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predsgr, 
                                        cmap = 'magma')
plt.title('Popularity GradientBoost')

plt.tight_layout()
plt.savefig('./images/gr_simple_cmatrix');

# %% [markdown]
# ## Classifying Genre Based on Audio Features

# %%
df2 = pd.read_csv('./data/artist_genre.csv')
df2
# Out:
#         artist_name                 genre  \
# 0       Frank Ocean               hip hop
# 1       Frank Ocean        lgbtq+ hip hop
# 2       Frank Ocean              neo soul
# 3       Frank Ocean                   pop
# 4       David Bowie              art rock
# ...             ...                   ...
# 32572  Dustin Lynch  contemporary country
# 32573  Dustin Lynch               country
# 32574  Dustin Lynch          country road
# 32575  Dustin Lynch   modern country rock
# 32576    Time Shard                   NaN
#
#                                         track_name                track_id  \
# 0                                             Lost  3GZD6HmiNUhxXYf8Gch723
# 1                                             Lost  3GZD6HmiNUhxXYf8Gch723
# 2                                             Lost  3GZD6HmiNUhxXYf8Gch723
# 3                                             Lost  3GZD6HmiNUhxXYf8Gch723
# 4                       Five Years - 2012 Remaster  1JIzFhI9Lt5FyslawmHCBi
# ...                                            ...                     ...
# 32572  Thinking 'Bout You (feat. MacKenzie Porter)  4wBjKhJx6JnGoNJfJs24pd
# 32573  Thinking 'Bout You (feat. MacKenzie Porter)  4wBjKhJx6JnGoNJfJs24pd
# 32574  Thinking 'Bout You (feat. MacKenzie Porter)  4wBjKhJx6JnGoNJfJs24pd
# 32575  Thinking 'Bout You (feat. MacKenzie Porter)  4wBjKhJx6JnGoNJfJs24pd
# 32576           Voodoo Chronometer - 2022 Remaster  0Y6jZQ942ExYc3DwkbjNUD
#
#        popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0              85         0.913   0.603    8    -4.892     1       0.2260
# 1              85         0.913   0.603    8    -4.892     1       0.2260
# 2              85         0.913   0.603    8    -4.892     1       0.2260
# 3              85         0.913   0.603    8    -4.892     1       0.2260
# 4              59         0.460   0.326    7   -10.699     1       0.0417
# ...           ...           ...     ...  ...       ...   ...          ...
# 32572          71         0.403   0.711    8    -4.189     1       0.0569
# 32573          71         0.403   0.711    8    -4.189     1       0.0569
# 32574          71         0.403   0.711    8    -4.189     1       0.0569
# 32575          71         0.403   0.711    8    -4.189     1       0.0569
# 32576           0         0.573   0.882   11    -9.497     0       0.0410
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.027200          0.000503    0.1670    0.497  123.061
# 1          0.027200          0.000503    0.1670    0.497  123.061
# 2          0.027200          0.000503    0.1670    0.497  123.061
# 3          0.027200          0.000503    0.1670    0.497  123.061
# 4          0.142000          0.000010    0.0449    0.321  152.531
# ...             ...               ...       ...      ...      ...
# 32572      0.137000          0.000000    0.1090    0.801  203.803
# 32573      0.137000          0.000000    0.1090    0.801  203.803
# 32574      0.137000          0.000000    0.1090    0.801  203.803
# 32575      0.137000          0.000000    0.1090    0.801  203.803
# 32576      0.000142          0.892000    0.1370    0.630  130.822
#
#        duration_ms  time_signature
# 0           234093               4
# 1           234093               4
# 2           234093               4
# 3           234093               4
# 4           283753               3
# ...            ...             ...
# 32572       170560               4
# 32573       170560               4
# 32574       170560               4
# 32575       170560               4
# 32576       470787               4
#
# [32577 rows x 18 columns]

# %%
df2['genre'].value_counts()
# Out:
# pop                      1733
# rap                      1152
# dance pop                 858
# hip hop                   706
# rock                      702
#                          ...
# virgin islands reggae       1
# chilena                     1
# veracruz indie              1
# modern big band             1
# argentine ambient           1
# Name: genre, Length: 1299, dtype: int64

# %%
df2.isnull().sum()
# Out:
# artist_name            0
# genre               1703
# track_name             0
# track_id               0
# popularity             0
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# tempo                  0
# duration_ms            0
# time_signature         0
# dtype: int64

# %%
df2.dropna(inplace = True)

# %%
print(df.shape)
df2.isnull().sum()
# Out:
# (10064, 2589)
# artist_name         0
# genre               0
# track_name          0
# track_id            0
# popularity          0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
df2
# Out:
#         artist_name                 genre  \
# 0       Frank Ocean               hip hop
# 1       Frank Ocean        lgbtq+ hip hop
# 2       Frank Ocean              neo soul
# 3       Frank Ocean                   pop
# 4       David Bowie              art rock
# ...             ...                   ...
# 32570        Eminem                   rap
# 32572  Dustin Lynch  contemporary country
# 32573  Dustin Lynch               country
# 32574  Dustin Lynch          country road
# 32575  Dustin Lynch   modern country rock
#
#                                         track_name                track_id  \
# 0                                             Lost  3GZD6HmiNUhxXYf8Gch723
# 1                                             Lost  3GZD6HmiNUhxXYf8Gch723
# 2                                             Lost  3GZD6HmiNUhxXYf8Gch723
# 3                                             Lost  3GZD6HmiNUhxXYf8Gch723
# 4                       Five Years - 2012 Remaster  1JIzFhI9Lt5FyslawmHCBi
# ...                                            ...                     ...
# 32570                                     Darkness  48aI5wAluvSrq55EAR329i
# 32572  Thinking 'Bout You (feat. MacKenzie Porter)  4wBjKhJx6JnGoNJfJs24pd
# 32573  Thinking 'Bout You (feat. MacKenzie Porter)  4wBjKhJx6JnGoNJfJs24pd
# 32574  Thinking 'Bout You (feat. MacKenzie Porter)  4wBjKhJx6JnGoNJfJs24pd
# 32575  Thinking 'Bout You (feat. MacKenzie Porter)  4wBjKhJx6JnGoNJfJs24pd
#
#        popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0              85         0.913   0.603    8    -4.892     1       0.2260
# 1              85         0.913   0.603    8    -4.892     1       0.2260
# 2              85         0.913   0.603    8    -4.892     1       0.2260
# 3              85         0.913   0.603    8    -4.892     1       0.2260
# 4              59         0.460   0.326    7   -10.699     1       0.0417
# ...           ...           ...     ...  ...       ...   ...          ...
# 32570          53         0.608   0.623    2    -7.239     1       0.3070
# 32572          71         0.403   0.711    8    -4.189     1       0.0569
# 32573          71         0.403   0.711    8    -4.189     1       0.0569
# 32574          71         0.403   0.711    8    -4.189     1       0.0569
# 32575          71         0.403   0.711    8    -4.189     1       0.0569
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 0           0.02720          0.000503    0.1670    0.497  123.061
# 1           0.02720          0.000503    0.1670    0.497  123.061
# 2           0.02720          0.000503    0.1670    0.497  123.061
# 3           0.02720          0.000503    0.1670    0.497  123.061
# 4           0.14200          0.000010    0.0449    0.321  152.531
# ...             ...               ...       ...      ...      ...
# 32570       0.00833          0.000039    0.6020    0.171   74.344
# 32572       0.13700          0.000000    0.1090    0.801  203.803
# 32573       0.13700          0.000000    0.1090    0.801  203.803
# 32574       0.13700          0.000000    0.1090    0.801  203.803
# 32575       0.13700          0.000000    0.1090    0.801  203.803
#
#        duration_ms  time_signature
# 0           234093               4
# 1           234093               4
# 2           234093               4
# 3           234093               4
# 4           283753               3
# ...            ...             ...
# 32570       338493               4
# 32572       170560               4
# 32573       170560               4
# 32574       170560               4
# 32575       170560               4
#
# [30874 rows x 18 columns]

# %%
X = df2.drop(columns = ['genre', 'artist_name', 'track_name', 'track_id'])
y = df2['genre']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
start = timeit.default_timer()

logreg = LogisticRegression(max_iter = 10000)
logreg.fit(X_train, y_train)

print(f'Train: {logreg.score(X_train, y_train)}')
print(f'Test: {logreg.score(X_test, y_test)}')

stop = timeit.default_timer()
print ('Time to run this code (in seconds):', stop - start)
# Out:
# C:\Users\sbhew\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Train: 0.08244439645864823
# Test: 0.0757870190439176
# Time to run this code (in seconds): 8975.739348199999

# %%
start = timeit.default_timer()

rf = RandomForestClassifier()
rf.fit(X_train, y_train)

print(f'Train: {rf.score(X_train, y_train)}')
print(f'Test: {rf.score(X_test, y_test)}')

stop = timeit.default_timer()
print ('Time to run this code (in seconds):', stop - start)
# Out:
# Train: 0.34156769596199527
# Test: 0.022541780023319084
# Time to run this code (in seconds): 61.71685760000037

# %%
start = timeit.default_timer()

gr = GradientBoostingClassifier()
gr.fit(X_train, y_train)

print(f'Train: {gr.score(X_train, y_train)}')
print(f'Test: {gr.score(X_test, y_test)}')

stop = timeit.default_timer()
print ('Time to run this code (in seconds):', stop - start)

# %%
start = timeit.default_timer()

ada = AdaBoostClassifier()
ada.fit(X_train, y_train)

print(f'Train: {ada.score(X_train, y_train)}')
print(f'Test: {ada.score(X_test, y_test)}')

stop = timeit.default_timer()
print ('Time to run this code (in seconds):', stop - start)
