# %% [markdown]
# # Data Collection and Cleaning

# %%
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
import spotipy
import time
import timeit
import pprint
import pandas as pd
import numpy as np

# %% [markdown]
# Used Spotipy and Spotify Web API to extract data

# %%
cid = "0f298608fe46432daff4e6304d5607bd" 
secret = 

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 
sp = spotipy.Spotify(auth_manager = spotipy.SpotifyOAuth(client_id = cid, client_secret = secret,
                            redirect_uri = "http://localhost:8888/callback",
                            scope = "user-library-read",
                            open_browser=False))

# %%
# recent saved tracks
results = sp.current_user_saved_tracks()
for idx, item in enumerate(results['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'],  " – ", track['id'],  " – ", track['popularity'])
# Out:
# 0 CORPSE  –  life waster  –  6TCKkbyGVo5uvTEfJvkcE3  –  68
# 1 CORPSE  –  agoraphobic  –  6ATqL4f1nFWwASrWi8nF6e  –  68
# 2 CORPSE  –  MISA MISA!  –  3bpR5jv8uzraDgq5YpHwDw  –  80
# 3 Hechizeros Band  –  El Sonidito  –  3kCeW0fmkrLBWCpEGazRMR  –  59
# 4 CHUNG HA  –  Sparkling  –  34lKiKHCKhMe9PAfGcdFNE  –  57
# 5 TWICE  –  Basics  –  63mL1DdcSFfxVJ9XGnSRQz  –  74
# 6 Rosa Walton  –  I Really Want to Stay at Your House  –  7mykoq6R3BArsSpNDjFQTm  –  81
# 7 salute  –  Ultra Pool  –  5ImmZZSkWdwqXDElBjUsdE  –  31
# 8 COBRAH  –  GOOD PUSS  –  3VBWOEqwknZm2NQjuvCPUd  –  45
# 9 BIBI  –  BAD SAD AND MAD  –  0zPbUxvYRlCGwruakkXPLI  –  64
# 10 88rising  –  The Weekend - MILLI Remix  –  1XVQu6SXMMEJ3nc9BOGhgk  –  63
# 11 TWICE  –  Talk that Talk  –  0RDqNCRBGrSegk16Avfzuq  –  87
# 12 Joji  –  YUKON (INTERLUDE)  –  3ZQLH6uKCfvgkbnMSVNCQe  –  69
# 13 88rising  –  Best Lover  –  0iWFz0Q5Qha9bx325ocFWq  –  65
# 14 f(x)  –  Rude Love  –  3hgnOyJFaj7RGhPeBDhonx  –  39
# 15 NIKI  –  High School in Jakarta  –  5rbuv6zso7QSaKt265H3M3  –  79
# 16 Whitney Houston  –  How Will I Know  –  79wbJeLkXOlJh4AzaWCWfL  –  74
# 17 NIKI  –  move!  –  1TrlQEbfqvcxqRXT4qr5sa  –  45
# 18 1nonly  –  Stay With Me  –  2WYs5LxOZfEyURXu7V0O1a  –  80
# 19 Machine Girl  –  Ghost  –  4orMsymF399H3xKBc0AIhx  –  60

# %%
artist_name = []
track_name = []
track_id = []
popularity = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2022', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
track_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_df.shape)
track_df
# Out:
# (1000, 4)
#       artist_name                 track_name                track_id  \
# 0       Sam Smith  Unholy (feat. Kim Petras)  3nqQXoyQOWXiESFLlDF1hG
# 1            d4vd          Romantic Homicide  1xK59OXxi2TAAAbmZK0kBL
# 2         Beyoncé                    CUFF IT  1xzi1Jcr7mEi9K2RfzLOqS
# 3            JVKE                golden hour  6GD1eomgaGT1Epto6Q5eAo
# 4      Steve Lacy                  Bad Habit  4k6Uh1HXdhtusDW5y8Gbvy
# ..            ...                        ...                     ...
# 995          Feid                PURRITO APA  2HMuxjDbADZm2XQB9z9LAF
# 996          Feid                PURRITO APA  26M0lpaQPaLQmUBAiIz2Hw
# 997  David Guetta                 Let's Love  1j1kIOeU1cH85D5BHNVvbb
# 998  David Guetta                   Memories  5xJzKANOOTcnqk5EuzaCGh
# 999    Zach Bryan           The Good I'll Do  53zCCom4uEoIBaOAEJtjUL
#
#      popularity
# 0            91
# 1            89
# 2            88
# 3            89
# 4            88
# ..          ...
# 995           0
# 996           0
# 997           0
# 998           0
# 999          66
#
# [1000 rows x 4 columns]

# %%
track_df['track_id']
# Out:
# 0      3nqQXoyQOWXiESFLlDF1hG
# 1      1xK59OXxi2TAAAbmZK0kBL
# 2      1xzi1Jcr7mEi9K2RfzLOqS
# 3      6GD1eomgaGT1Epto6Q5eAo
# 4      4k6Uh1HXdhtusDW5y8Gbvy
#                 ...
# 995    2HMuxjDbADZm2XQB9z9LAF
# 996    26M0lpaQPaLQmUBAiIz2Hw
# 997    1j1kIOeU1cH85D5BHNVvbb
# 998    5xJzKANOOTcnqk5EuzaCGh
# 999    53zCCom4uEoIBaOAEJtjUL
# Name: track_id, Length: 1000, dtype: object

# %%
sp.audio_features('5zIXVqJifYPQrom15l3eI3')[0]
# Out:
# {'danceability': 0.558,
#  'energy': 0.838,
#  'key': 7,
#  'loudness': -6.479,
#  'mode': 1,
#  'speechiness': 0.0417,
#  'acousticness': 0.0612,
#  'instrumentalness': 0.00182,
#  'liveness': 0.309,
#  'valence': 0.778,
#  'tempo': 119.089,
#  'type': 'audio_features',
#  'id': '5zIXVqJifYPQrom15l3eI3',
#  'uri': 'spotify:track:5zIXVqJifYPQrom15l3eI3',
#  'track_href': 'https://api.spotify.com/v1/tracks/5zIXVqJifYPQrom15l3eI3',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5zIXVqJifYPQrom15l3eI3',
#  'duration_ms': 191107,
#  'time_signature': 4}

# %%
sp.audio_features('0RDqNCRBGrSegk16Avfzuq')
# Out:
# [{'danceability': 0.772,
#   'energy': 0.907,
#   'key': 3,
#   'loudness': -2.438,
#   'mode': 0,
#   'speechiness': 0.124,
#   'acousticness': 0.136,
#   'instrumentalness': 0,
#   'liveness': 0.334,
#   'valence': 0.783,
#   'tempo': 119.973,
#   'type': 'audio_features',
#   'id': '0RDqNCRBGrSegk16Avfzuq',
#   'uri': 'spotify:track:0RDqNCRBGrSegk16Avfzuq',
#   'track_href': 'https://api.spotify.com/v1/tracks/0RDqNCRBGrSegk16Avfzuq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0RDqNCRBGrSegk16Avfzuq',
#   'duration_ms': 177467,
#   'time_signature': 4}]

# %%
sp.audio_features('0qM0FYeAgpZaWhuiGgSioF')
# Out:
# [{'danceability': 0.645,
#   'energy': 0.71,
#   'key': 11,
#   'loudness': -8.342,
#   'mode': 0,
#   'speechiness': 0.473,
#   'acousticness': 0.29,
#   'instrumentalness': 0,
#   'liveness': 0.524,
#   'valence': 0.801,
#   'tempo': 134.27,
#   'type': 'audio_features',
#   'id': '0qM0FYeAgpZaWhuiGgSioF',
#   'uri': 'spotify:track:0qM0FYeAgpZaWhuiGgSioF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0qM0FYeAgpZaWhuiGgSioF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0qM0FYeAgpZaWhuiGgSioF',
#   'duration_ms': 51445,
#   'time_signature': 4}]

# %% [markdown]
# ---
# Function to get tracks by year. Running into API error where some songs in specific years are missing audio features

# %%
def get_tracks_to_csv(year):
    artist_name = []
    artist_genre = []
    track_name = []
    track_id = []
    popularity = []
    year_list = []
    
    for i in range(0,1000,50):
        track_results = sp.search(q=f'year:{year}', type='track', limit=50,offset=i)
        for i, t in enumerate(track_results['tracks']['items']):
            artist_name.append(t['artists'][0]['name'])
            artist_genre.append(sp.artist(track_results['tracks']['items'][i]['artists'][0]['uri'])['genres'])
            track_name.append(t['name'])
            track_id.append(t['id'])
            popularity.append(t['popularity'])
            year_list.append(year)
    track_df = pd.DataFrame({'artist_name' : artist_name, 'artist_genre' : artist_genre, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity, 'year' : year})



    dict_list=[]
    for track in track_df['track_id']:
        dict_list.append(sp.audio_features(track)[0])
        
    #removes songs that have no audio features error
    dict_list_2 = []
    for i in range(len(dict_list)):
        if type(dict_list[i]) == dict:
            dict_list_2.append(dict_list[i]) 

    audio_feat_df = pd.DataFrame(dict_list_2)

    merged_df = track_df.merge(audio_feat_df, left_on='track_id', right_on='id')
    merged_df = merged_df.drop_duplicates(subset = ['track_id'], keep = 'last')
    merged_df.to_csv(f'../data/oct_tracks_{year}.csv', index = False)
    return

# %%
years = []
for i in range(2012, 2023):
    years.append(i)
    
for year in years:
    get_tracks_to_csv(year)
    print(f'{year} data collected')
# Out:
# 2012 data collected
# 2013 data collected
# 2014 data collected
# 2015 data collected
# 2016 data collected
# 2017 data collected
# 2018 data collected
# 2019 data collected
# 2020 data collected
# 2021 data collected
# 2022 data collected

# %% [markdown]
# ### Data Cleaning

# %%
# merging dataframes
for year in years:
    globals()[f'df_{year}'] = pd.read_csv(f'../data/oct_tracks_{year}.csv')

frames = [df_2012, df_2013, df_2014, df_2015, df_2016, df_2017, 
          df_2018, df_2019, df_2020, df_2021, df_2022]
merged_df = pd.concat(frames)
merged_df = merged_df.drop_duplicates()
merged_df.drop(columns = ['type', 'id', 'uri', 'track_href', 'analysis_url'], inplace = True)
merged_df
# Out:
#           artist_name                                       artist_genre  \
# 0         Frank Ocean   ['hip hop', 'lgbtq+ hip hop', 'neo soul', 'pop']
# 1    Carly Rae Jepsen  ['canadian pop', 'dance pop', 'electropop', 'p...
# 2                Zedd  ['complextro', 'dance pop', 'edm', 'electro ho...
# 3                fun.  ['baroque pop', 'metropopolis', 'modern rock',...
# 4         Frank Ocean   ['hip hop', 'lgbtq+ hip hop', 'neo soul', 'pop']
# ..                ...                                                ...
# 994              Feid  ['colombian pop', 'pop reggaeton', 'reggaeton ...
# 995              Feid  ['colombian pop', 'pop reggaeton', 'reggaeton ...
# 996              Feid  ['colombian pop', 'pop reggaeton', 'reggaeton ...
# 997      David Guetta  ['big room', 'dance pop', 'edm', 'pop', 'pop d...
# 998        Zach Bryan                               ['oklahoma country']
#
#                              track_name                track_id  popularity  \
# 0                      Thinkin Bout You  7DfFc7a6Rwfi3YQMRbDMau          78
# 1                         Call Me Maybe  3TGRqZ0a2l1LRblBkJoaDx          72
# 2                               Clarity  60wwxj6Dd9NJlirf84wr2c          75
# 3    We Are Young (feat. Janelle Monáe)  7a86XRg84qjasly9f6bPSD          74
# 4                       Super Rich Kids  0725YWm6Z0TpZ6wrNk64Eb          74
# ..                                  ...                     ...         ...
# 994                         PURRITO APA  2HMuxjDbADZm2XQB9z9LAF           0
# 995                                 911  55cGYuLq9uRveGoQ1uzI3j           0
# 996                         PURRITO APA  26M0lpaQPaLQmUBAiIz2Hw           0
# 997                          Let's Love  1j1kIOeU1cH85D5BHNVvbb           0
# 998                    The Good I'll Do  53zCCom4uEoIBaOAEJtjUL          66
#
#      year  danceability  energy  key  loudness  mode  speechiness  \
# 0    2012         0.721   0.339    0   -11.195     1       0.0532
# 1    2012         0.783   0.580    7    -6.548     1       0.0408
# 2    2012         0.509   0.781    8    -3.480     1       0.0720
# 3    2012         0.378   0.638   10    -5.576     1       0.0750
# 4    2012         0.739   0.419    3    -8.241     0       0.0854
# ..    ...           ...     ...  ...       ...   ...          ...
# 994  2022         0.626   0.662    6    -4.104     1       0.3290
# 995  2022         0.798   0.857    6    -3.748     1       0.1050
# 996  2022         0.626   0.662    6    -4.104     1       0.3290
# 997  2022         0.662   0.868    5    -4.025     1       0.0341
# 998  2022         0.434   0.215   10    -8.478     1       0.0417
#
#      acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0         0.40900          0.001530    0.0973    0.200  129.830       200747
# 1         0.01140          0.000002    0.1080    0.660  120.021       193400
# 2         0.03980          0.000000    0.0749    0.176  128.000       271427
# 3         0.02000          0.000077    0.0849    0.735  184.086       250627
# 4         0.21900          0.000000    0.1960    0.580   60.493       304760
# ..            ...               ...       ...      ...      ...          ...
# 994       0.04600          0.000000    0.0942    0.632  110.611       151400
# 995       0.05190          0.000050    0.1420    0.581  102.998       221760
# 996       0.04600          0.000000    0.0942    0.632  110.611       151400
# 997       0.00882          0.002440    0.5840    0.353   92.998       200645
# 998       0.82000          0.000000    0.4560    0.187  118.152       211316
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 994               5
# 995               4
# 996               5
# 997               4
# 998               4
#
# [10994 rows x 19 columns]

# %%
merged_df.to_csv('../data/oct_merged_tracks.csv', index = False)

# %%
merged_df.to_excel('../data/oct_merged_tracks.xlsx', index = False)

# %% [markdown]
# ## 2021 tracks
# Note: Track ID **0qM0FYeAgpZaWhuiGgSioF** had no audio features on 8/8, but suddenly did on 8/9

# %%
artist_name = []
artist_genre = []
track_name = []
popularity = []
track_id = []
year = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2021', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_genre.append(sp.artist(track_results['tracks']['items'][i]['artists'][0]['uri'])['genres'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
        year.append('2021')

# %%
#track_results['tracks']['items'][0]['artists'][0]['uri']

# %%
track_2021_df = pd.DataFrame({'artist_name' : artist_name, 'artist_genre' : artist_genre, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity, 'year' : year})
track_2021_df
# Out:
#           artist_name                                       artist_genre  \
# 0     Stephen Sanchez                     [gen z singer-songwriter, pop]
# 1                 AJR                                      [modern rock]
# 2              Cafuné                                   [brooklyn indie]
# 3          Elton John               [glam rock, mellow gold, piano rock]
# 4       The Kid LAROI                          [australian hip hop, pop]
# ..                ...                                                ...
# 995      Ivan Cornejo                            [nueva musica mexicana]
# 996   Scotty McCreery  [contemporary country, country, country road, ...
# 997  Los Dos Carnales  [corrido, musica mexicana, norteno, nueva musi...
# 998      Taylor Swift                                              [pop]
# 999   Jameson Rodgers  [contemporary country, country, country pop, c...
#
#                          track_name                track_id  popularity  year
# 0                 Until I Found You  0T5iIrXA4p5GsubkhuBIKV          90  2021
# 1           World's Smallest Violin  3jHBgKdLCf46aP3HRI0WYv          78  2021
# 2                            Tek It  751srcHf5tUqcEa9pRCQwP          80  2021
# 3           Cold Heart - PNAU Remix  6zSpb8dQRaw0M1dK8PBwQz          89  2021
# 4         STAY (with Justin Bieber)  5HCyWlXZPP0y6Gqq8TgA20          89  2021
# ..                              ...                     ...         ...   ...
# 995                    Corazón Frio  3a0EjZTzCLx1ztmtaZb9Cp          62  2021
# 996                     Damn Strait  0gNrujgnSfw4LuSvd0Jbs6          62  2021
# 997                   Me Vale Madre  2bgzjBJcfn0r0HkJ0N2Lzx          70  2021
# 998  Holy Ground (Taylor's Version)  7J4b3LVCIGO4CMBDFLPoP6          67  2021
# 999       Cold Beer Calling My Name  67wUHsoXdZ8UOLt6rodpQ9          63  2021
#
# [1000 rows x 6 columns]

# %%
artist_name = []
artist_genre = []
artist_id = []
track_name = []
popularity = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2021', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        artist_genre.append(sp.artist(artist_uri)['genres'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
track_2021_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_df.shape)
track_2021_df
# Out:
# (1000, 4)
#                           artist_name  \
# 0                         Nicky Youre
# 1                           Dj Biffen
# 2                       Morgan Wallen
# 3    Elvis Costello & The Attractions
# 4                               Drake
# ..                                ...
# 995                              K120
# 996                             Nic D
# 997                           Tutxtut
# 998                           JELEEL!
# 999                        Matt Monro
#
#                                             track_name  \
# 0                                              Sunroof
# 1    Merry Christmas and Happy New Year 2021 - Radi...
# 2                                        Wasted On You
# 3                           Pump It Up - 2021 Remaster
# 4          Knife Talk (with 21 Savage ft. Project Pat)
# ..                                                 ...
# 995     It's Christmas, You Are 13 Years Old and Happy
# 996                                           Icee Pop
# 997                                               2021
# 998                                           DIVE IN!
# 999                     Spanish Eyes - Remastered 2021
#
#                    track_id  popularity
# 0    4h4QlmocP3IuwYEj2j14p8          91
# 1    7h7yPyss4MIBVPXVeF83vg          19
# 2    3cBsEDNhFI9E82vPj3kvi3          82
# 3    3oyc1mIdCBGaU55wX7otqM          61
# 4    2BcMwX1MPV6ZHP4tUT9uq6          85
# ..                      ...         ...
# 995  4viQSBJ8rdw7ix4lHUYMKp          14
# 996  1zKOagmkCtXuGmCivG8HZE          69
# 997  1B7KBqFVGzqmVAK9b4WbJh           0
# 998  192DMwgDbgS8ghTKc0ACWq          71
# 999  0vkxr7keQKoqz55l6ETXG6          16
#
# [1000 rows x 4 columns]

# %%
dict_list_2021=[]
for track in track_2021_df['track_id']:
    dict_list_2021.append(sp.audio_features(track)[0])
audio_feat_2021_df = pd.DataFrame(dict_list_2021)
audio_feat_2021_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.768   0.714   10    -5.110     1       0.0401       0.35200
# 1           0.887   0.633    8   -10.453     1       0.0660       0.06290
# 2           0.505   0.657   11    -5.240     0       0.0318       0.37300
# 3           0.645   0.809   11    -6.120     1       0.0385       0.00921
# 4           0.849   0.424    5    -9.579     0       0.3240       0.06350
# ..            ...     ...  ...       ...   ...          ...           ...
# 995         0.676   0.555    7   -12.511     1       0.0489       0.03030
# 996         0.914   0.572    0    -6.606     1       0.0359       0.12000
# 997         0.818   0.681    7   -10.665     0       0.4760       0.15500
# 998         0.700   0.792    6    -5.280     1       0.0459       0.00128
# 999         0.531   0.385    7   -12.718     1       0.0545       0.53000
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000000    0.1500   0.8420  131.443  audio_features
# 1            0.922000    0.0637   0.8490  130.023  audio_features
# 2            0.001070    0.1260   0.2520  196.000  audio_features
# 3            0.001080    0.1060   0.9660  138.978  audio_features
# 4            0.000000    0.0834   0.1530  145.887  audio_features
# ..                ...       ...      ...      ...             ...
# 995          0.907000    0.2050   0.7200  163.951  audio_features
# 996          0.000000    0.0709   0.8640  134.989  audio_features
# 997          0.000000    0.0914   0.0601   97.196  audio_features
# 998          0.000076    0.3750   0.4220  139.978  audio_features
# 999          0.000000    0.2500   0.6030  115.897  audio_features
#
#                          id                                   uri  \
# 0    4h4QlmocP3IuwYEj2j14p8  spotify:track:4h4QlmocP3IuwYEj2j14p8
# 1    7h7yPyss4MIBVPXVeF83vg  spotify:track:7h7yPyss4MIBVPXVeF83vg
# 2    3cBsEDNhFI9E82vPj3kvi3  spotify:track:3cBsEDNhFI9E82vPj3kvi3
# 3    3oyc1mIdCBGaU55wX7otqM  spotify:track:3oyc1mIdCBGaU55wX7otqM
# 4    2BcMwX1MPV6ZHP4tUT9uq6  spotify:track:2BcMwX1MPV6ZHP4tUT9uq6
# ..                      ...                                   ...
# 995  4viQSBJ8rdw7ix4lHUYMKp  spotify:track:4viQSBJ8rdw7ix4lHUYMKp
# 996  1zKOagmkCtXuGmCivG8HZE  spotify:track:1zKOagmkCtXuGmCivG8HZE
# 997  1B7KBqFVGzqmVAK9b4WbJh  spotify:track:1B7KBqFVGzqmVAK9b4WbJh
# 998  192DMwgDbgS8ghTKc0ACWq  spotify:track:192DMwgDbgS8ghTKc0ACWq
# 999  0vkxr7keQKoqz55l6ETXG6  spotify:track:0vkxr7keQKoqz55l6ETXG6
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/4h4QlmocP3Iu...
# 1    https://api.spotify.com/v1/tracks/7h7yPyss4MIB...
# 2    https://api.spotify.com/v1/tracks/3cBsEDNhFI9E...
# 3    https://api.spotify.com/v1/tracks/3oyc1mIdCBGa...
# 4    https://api.spotify.com/v1/tracks/2BcMwX1MPV6Z...
# ..                                                 ...
# 995  https://api.spotify.com/v1/tracks/4viQSBJ8rdw7...
# 996  https://api.spotify.com/v1/tracks/1zKOagmkCtXu...
# 997  https://api.spotify.com/v1/tracks/1B7KBqFVGzqm...
# 998  https://api.spotify.com/v1/tracks/192DMwgDbgS8...
# 999  https://api.spotify.com/v1/tracks/0vkxr7keQKoq...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/4h4Q...       163026
# 1    https://api.spotify.com/v1/audio-analysis/7h7y...       176363
# 2    https://api.spotify.com/v1/audio-analysis/3cBs...       178520
# 3    https://api.spotify.com/v1/audio-analysis/3oyc...       196680
# 4    https://api.spotify.com/v1/audio-analysis/2BcM...       242966
# ..                                                 ...          ...
# 995  https://api.spotify.com/v1/audio-analysis/4viQ...        96602
# 996  https://api.spotify.com/v1/audio-analysis/1zKO...       147556
# 997  https://api.spotify.com/v1/audio-analysis/1B7K...       171938
# 998  https://api.spotify.com/v1/audio-analysis/192D...       100500
# 999  https://api.spotify.com/v1/audio-analysis/0vkx...       144790
#
#      time_signature
# 0                 4
# 1                 4
# 2                 3
# 3                 4
# 4                 4
# ..              ...
# 995               4
# 996               4
# 997               4
# 998               4
# 999               3
#
# [1000 rows x 18 columns]

# %%
merged_2021_df = track_2021_df.merge(audio_feat_2021_df, left_on='track_id', right_on='id')
merged_2021_df = merged_2021_df.drop_duplicates(subset = ['track_id'], keep = 'last')
merged_2021_df
# Out:
#                            artist_name  \
# 0                          Nicky Youre
# 1                            Dj Biffen
# 2                        Morgan Wallen
# 3     Elvis Costello & The Attractions
# 4                                Drake
# ...                                ...
# 1073                              K120
# 1074                             Nic D
# 1075                           Tutxtut
# 1076                           JELEEL!
# 1077                        Matt Monro
#
#                                              track_name  \
# 0                                               Sunroof
# 1     Merry Christmas and Happy New Year 2021 - Radi...
# 2                                         Wasted On You
# 3                            Pump It Up - 2021 Remaster
# 4           Knife Talk (with 21 Savage ft. Project Pat)
# ...                                                 ...
# 1073     It's Christmas, You Are 13 Years Old and Happy
# 1074                                           Icee Pop
# 1075                                               2021
# 1076                                           DIVE IN!
# 1077                     Spanish Eyes - Remastered 2021
#
#                     track_id  popularity  danceability  energy  key  loudness  \
# 0     4h4QlmocP3IuwYEj2j14p8          91         0.768   0.714   10    -5.110
# 1     7h7yPyss4MIBVPXVeF83vg          19         0.887   0.633    8   -10.453
# 2     3cBsEDNhFI9E82vPj3kvi3          82         0.505   0.657   11    -5.240
# 3     3oyc1mIdCBGaU55wX7otqM          61         0.645   0.809   11    -6.120
# 4     2BcMwX1MPV6ZHP4tUT9uq6          85         0.849   0.424    5    -9.579
# ...                      ...         ...           ...     ...  ...       ...
# 1073  4viQSBJ8rdw7ix4lHUYMKp          14         0.676   0.555    7   -12.511
# 1074  1zKOagmkCtXuGmCivG8HZE          69         0.914   0.572    0    -6.606
# 1075  1B7KBqFVGzqmVAK9b4WbJh           0         0.818   0.681    7   -10.665
# 1076  192DMwgDbgS8ghTKc0ACWq          71         0.700   0.792    6    -5.280
# 1077  0vkxr7keQKoqz55l6ETXG6          16         0.531   0.385    7   -12.718
#
#       mode  speechiness  ...  liveness  valence    tempo            type  \
# 0        1       0.0401  ...    0.1500   0.8420  131.443  audio_features
# 1        1       0.0660  ...    0.0637   0.8490  130.023  audio_features
# 2        0       0.0318  ...    0.1260   0.2520  196.000  audio_features
# 3        1       0.0385  ...    0.1060   0.9660  138.978  audio_features
# 4        0       0.3240  ...    0.0834   0.1530  145.887  audio_features
# ...    ...          ...  ...       ...      ...      ...             ...
# 1073     1       0.0489  ...    0.2050   0.7200  163.951  audio_features
# 1074     1       0.0359  ...    0.0709   0.8640  134.989  audio_features
# 1075     0       0.4760  ...    0.0914   0.0601   97.196  audio_features
# 1076     1       0.0459  ...    0.3750   0.4220  139.978  audio_features
# 1077     1       0.0545  ...    0.2500   0.6030  115.897  audio_features
#
#                           id                                   uri  \
# 0     4h4QlmocP3IuwYEj2j14p8  spotify:track:4h4QlmocP3IuwYEj2j14p8
# 1     7h7yPyss4MIBVPXVeF83vg  spotify:track:7h7yPyss4MIBVPXVeF83vg
# 2     3cBsEDNhFI9E82vPj3kvi3  spotify:track:3cBsEDNhFI9E82vPj3kvi3
# 3     3oyc1mIdCBGaU55wX7otqM  spotify:track:3oyc1mIdCBGaU55wX7otqM
# 4     2BcMwX1MPV6ZHP4tUT9uq6  spotify:track:2BcMwX1MPV6ZHP4tUT9uq6
# ...                      ...                                   ...
# 1073  4viQSBJ8rdw7ix4lHUYMKp  spotify:track:4viQSBJ8rdw7ix4lHUYMKp
# 1074  1zKOagmkCtXuGmCivG8HZE  spotify:track:1zKOagmkCtXuGmCivG8HZE
# 1075  1B7KBqFVGzqmVAK9b4WbJh  spotify:track:1B7KBqFVGzqmVAK9b4WbJh
# 1076  192DMwgDbgS8ghTKc0ACWq  spotify:track:192DMwgDbgS8ghTKc0ACWq
# 1077  0vkxr7keQKoqz55l6ETXG6  spotify:track:0vkxr7keQKoqz55l6ETXG6
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4h4QlmocP3Iu...
# 1     https://api.spotify.com/v1/tracks/7h7yPyss4MIB...
# 2     https://api.spotify.com/v1/tracks/3cBsEDNhFI9E...
# 3     https://api.spotify.com/v1/tracks/3oyc1mIdCBGa...
# 4     https://api.spotify.com/v1/tracks/2BcMwX1MPV6Z...
# ...                                                 ...
# 1073  https://api.spotify.com/v1/tracks/4viQSBJ8rdw7...
# 1074  https://api.spotify.com/v1/tracks/1zKOagmkCtXu...
# 1075  https://api.spotify.com/v1/tracks/1B7KBqFVGzqm...
# 1076  https://api.spotify.com/v1/tracks/192DMwgDbgS8...
# 1077  https://api.spotify.com/v1/tracks/0vkxr7keQKoq...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/4h4Q...      163026
# 1     https://api.spotify.com/v1/audio-analysis/7h7y...      176363
# 2     https://api.spotify.com/v1/audio-analysis/3cBs...      178520
# 3     https://api.spotify.com/v1/audio-analysis/3oyc...      196680
# 4     https://api.spotify.com/v1/audio-analysis/2BcM...      242966
# ...                                                 ...         ...
# 1073  https://api.spotify.com/v1/audio-analysis/4viQ...       96602
# 1074  https://api.spotify.com/v1/audio-analysis/1zKO...      147556
# 1075  https://api.spotify.com/v1/audio-analysis/1B7K...      171938
# 1076  https://api.spotify.com/v1/audio-analysis/192D...      100500
# 1077  https://api.spotify.com/v1/audio-analysis/0vkx...      144790
#
#      time_signature
# 0                 4
# 1                 4
# 2                 3
# 3                 4
# 4                 4
# ...             ...
# 1073              4
# 1074              4
# 1075              4
# 1076              4
# 1077              3
#
# [961 rows x 22 columns]

# %%
start = timeit.default_timer()

results = sp.search(q='twice', limit=20)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])

stop = timeit.default_timer()
print ('Time to run this code (in seconds):', stop - start)
# Out:
# 0 Talk that Talk
# 1 Basics
# 2 FANCY
# 3 Likey
# 4 What is Love
# 5 I CAN'T STOP ME
# 6 The Feels
# 7 Alcohol-Free
# 8 Twice
# 9 POP!
# 10 The Feels
# 11 TT
# 12 Trouble
# 13 Doughnut
# 14 Brave
# 15 Twice As Hard
# 16 Break Up Twice
# 17 Twice
# 18 You Only Live Twice (with Lil Wayne & Rick Ross)
# 19 Devil Always Made Me Think Twice
# Time to run this code (in seconds): 0.620052599999326

# %%
# users playlists
sp = spotipy.Spotify(auth_manager = spotipy.SpotifyOAuth(client_id = cid, client_secret = secret,
                            redirect_uri = "http://localhost:8888/callback",
                            scope = "playlist-read-private",
                            open_browser=False))
results = sp.current_user_playlists(limit=50)
for i, item in enumerate(results['items']):
    print("%d %s %s" % (i, item['name'], item['id']))
# Out:
# Go to the following URL: https://accounts.spotify.com/authorize?client_id=0f298608fe46432daff4e6304d5607bd&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A8888%2Fcallback&scope=playlist-read-private
# Enter the URL you were redirected to:  http://localhost:8888/callback?code=AQCL4FrCNn696tv8ULB7WNxl0LosseXlSqI-1XJp-kIkKdNvRH0_QaO9-cZXuFRodoP76FjntxdEhyC8TalbcNQ-hzfZYYo4Y6yx75TwsVWuZucgYeS_bbC_uoD74Wy_WZCT-PtCfOtTzer8EYnYDYliE2J55KBXVecYN3KBZoBieFejWYSCKFZTRd6qL7aHU5v8HdDk7WqJ
# 0 Share whatever you like 7f7oviGdx9TPEVpBpm2sQR
# 1 TWICE 4TH WORLD TOUR 'Ⅲ' 3iA20ztniCf3PDFwGpwWAV
# 2 When We Were Young Fest Playlist 5j0A0VY64GXN2OR1ugYacW
# 3 AUDREY NUNA Mix 37i9dQZF1EIV7DyQUiPGPj
# 4 Porter Robinson Mix 37i9dQZF1EIVekANNCHutz
# 5 Japanese Breakfast Mix 37i9dQZF1EIWiVFFbMUz7d
# 6 Megan Thee Stallion and I 4uOrVYljLRnuiGioNVHVLU
# 7 porter robinson : cherished music 1H163taKSeBERTtCu3R7bp
# 8 Jasmine 37i9dQZF1DX5IOhx43PGIa
# 9 music from DAVE 23qwzp0yfy4GMxO34YWcR4
# 10 NKOH Warm Ups 6XGujD8cSfKGqrJrgoKIC5
# 11 The 200 Best Songs of the 2010s 2ua9P1PJZ8vNU1ZOZq6tqe
# 12 This Is Yung Bae 37i9dQZF1DZ06evO1JQKJZ
# 13 Hula/Tahitian Basics 6knU9lcnx4vnynEP6QpdoH
# 14 SLORP 3pqOXRMNPdF9vpdkxhbNyc
# 15 ham 2ValR1wNUOoy0BowzsExiV
# 16 悲しい音楽 33Pb8m7dzLyCzUR3UBeAwN
# 17 SAD WINTER BOY 3OktKQC1OLJ5QFgTErrI6L
# 18 Favorites 7hMBUPSLUuZvynHuCGKIfb
# 19 Who hurt you??? 4j7N0oh95PtMspcN3I07sc
# 20 Songs That Get Drunk White Girls Excited 4FO2WXjS922s0RheaTYPZK
# 21 Hawaiian for Study Sesh 7amSLr5iSMVisZoGJZHpww
# 22 Studying 4Jqzo4TDdnGuxHCZavqEWu
# 23 Flume 3cdFgnkp3IW9SZoNEd3boL
# 24 Liked from Radio 07uevEOcZbr3DENsEgkbrT
# 25 Discover Weekly 37i9dQZEVXcQpYRXmgpHuq
# 26 xXemoXx 1ZAgL9rURolDegynCQFnOG
# 27 _(:3」z)_ 1rM73FyNGRJpiogIQ70z2X
# 28 Baby Driver: Music From The Motion Picture 6PDXrjun1PrnqOC2iFQity
# 29 80s Smash Hits 19PgP2QSGPcm6Ve8VhbtpG
# 30 ¯\_(ツ)_/¯  6rT2eY5UTovGt6EIWgwZ5x
# 31 音楽 5msGVDSCJRpMKWBU5JJcpk

# %%
# users top songs, (short term, mid term, long term)
sp = spotipy.Spotify(auth_manager = spotipy.SpotifyOAuth(client_id = cid, client_secret = secret,
                            redirect_uri = "http://localhost:8888/callback",
                            scope = "user-top-read",
                            open_browser=False))

ranges = ['short_term', 'medium_term', 'long_term']

for sp_range in ranges:
    print("range:", sp_range)
    results = sp.current_user_top_tracks(time_range=sp_range, limit=50)
    for i, item in enumerate(results['items']):
        print(i, item['name'], '-', item['artists'][0]['name'], '-',  item['id'])
    print()
    #print(idx, track['artists'][0]['name'], " – ", track['name'],  " – ", track['id'],  " – ", track['popularity'])
# Out:
# range: short_term
# Go to the following URL: https://accounts.spotify.com/authorize?client_id=0f298608fe46432daff4e6304d5607bd&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A8888%2Fcallback&scope=user-top-read
# Enter the URL you were redirected to:  http://localhost:8888/callback?code=AQBOR1EgEG1Sr6AlRD4UIZtFvEIGaajdwc7dfMO1Tn0-VFqUEUP5xFGxvjsRNh36aLBNYoXCL-kL1Qwvhub60GmjEP4RTwypLFMtR4IU6tfp8VTwciejFRolFIKyOJjTtGVm6IbAYimty0MJnrfoGLGTGiZ-hhuokVFUOZ06yYKg4yDknV0Ytk0jh6UlMQZGeg
# 0 Talk that Talk - TWICE - 0RDqNCRBGrSegk16Avfzuq
# 1 Basics - TWICE - 63mL1DdcSFfxVJ9XGnSRQz
# 2 Ultra Pool - salute - 5ImmZZSkWdwqXDElBjUsdE
# 3 GOOD PUSS - COBRAH - 3VBWOEqwknZm2NQjuvCPUd
# 4 Best Lover - 88rising - 0iWFz0Q5Qha9bx325ocFWq
# 5 YUKON (INTERLUDE) - Joji - 6c1yUgFlhUHLAM9hSDkVBq
# 6 BAD SAD AND MAD - BIBI - 0zPbUxvYRlCGwruakkXPLI
# 7 I Really Want to Stay at Your House - Rosa Walton - 7mykoq6R3BArsSpNDjFQTm
# 8 Stay With Me - 1nonly - 2WYs5LxOZfEyURXu7V0O1a
# 9 Rude Love - f(x) - 3hgnOyJFaj7RGhPeBDhonx
# 10 High School in Jakarta - NIKI - 5rbuv6zso7QSaKt265H3M3
# 11 Ghost - Machine Girl - 4orMsymF399H3xKBc0AIhx
results['next']:
    results = sp.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Celebrate
# Formula of Love: O+T=<3
# Perfect World
# Eyes Wide Open
# MORE & MORE
# &TWICE (Repackage)
# &TWICE
# Feel Special
# BDZ (Repackage)
# The year of "YES"
# YES or YES
# BDZ
# Summer Nights
# Merry & Happy
# Twicetagram
# Twicecoaster: Lane 2
# Twicecoaster: Lane 1

# %%
# get artist genres
def get_artist_genre(artist_uri):
    return sp.artist(artist_uri)['genres']

# %%
twice_uri = 'spotify:artist:7n2Ycct7Beij7Dj7meI4X0'
get_artist_genre(twice_uri)
# Out:
# ['k-pop', 'k-pop girl group']

# %%
sp.recommendations(seed_artists = [twice_uri], limit = 1)['tracks'][0]['album']['artists'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/5r1tUTxVSgvBHnoDuDODPH'},
#  'href': 'https://api.spotify.com/v1/artists/5r1tUTxVSgvBHnoDuDODPH',
#  'id': '5r1tUTxVSgvBHnoDuDODPH',
#  'name': 'IZ*ONE',
#  'type': 'artist',
#  'uri': 'spotify:artist:5r1tUTxVSgvBHnoDuDODPH'}

# %%
# get 5 artist recommendations based on artist uri
def get_artist_recs(artist_uri, num_recs):
    rec_list = []
    recs = sp.recommendations(seed_artists = [artist_uri], limit = num_recs)
    for i in range(num_recs):
        rec_list.append(recs['tracks'][i]['album']['artists'][0]['uri'])
        #print(recs['tracks'][i]['album']['artists'][0]['name'] + ' - ' + recs['tracks'][i]['album']['artists'][0]['uri'] )
    return rec_list

# %%
for i in range(len(get_artist_recs(twice_uri, 5))):
    print(sp.artist(get_artist_recs(twice_uri, 5)[i])['name'])
# Out:
# ITZY
# EVERGLOW
# TOMORROW X TOGETHER
# MAMAMOO
# TOMORROW X TOGETHER

# %%
# song previews
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
results = spotify.artist_top_tracks(twice_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : The Feels
# audio    : https://p.scdn.co/mp3-preview/6c85210d5bf3c056b49e2a6ce06abcc2a99d23fe?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b273c11578f0d39a2d639a92046d
#
# track    : I CAN'T STOP ME
# audio    : https://p.scdn.co/mp3-preview/d42dc55267423e80fbf8bffc1aaea7f04210486e?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b273dfb3ec8a83a71cd5bbc595e6
#
# track    : FANCY
# audio    : https://p.scdn.co/mp3-preview/3c733514a1ae8b4960ce1cca282fe922b9376b1b?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b273d0a0974a3a74ad0771a1f87d
#
# track    : What is Love
# audio    : https://p.scdn.co/mp3-preview/4896f7384033b08c79fc13e9ab236f249cb6de33?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b273d610ab817a71b377cbe54742
#
# track    : Celebrate
# audio    : https://p.scdn.co/mp3-preview/cfd9972b45793d83323e333a93710b398e6d670f?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b27396f409e230a8f42400c901f1
#
# track    : Alcohol-Free
# audio    : https://p.scdn.co/mp3-preview/f31234a1d4878a09f3db2a935cf39d90c68b5365?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b2732eeed5cdd28da11577ea8bf5
#
# track    : CRY FOR ME
# audio    : https://p.scdn.co/mp3-preview/8f4d947f17570e760908073ec1280cd5296f64b0?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b273cf3bd61dee85e0b7753decbd
#
# track    : SCIENTIST
# audio    : https://p.scdn.co/mp3-preview/b29a392071eacfaac31cf2d6eee23ad9de5394cb?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b273c11578f0d39a2d639a92046d
#
# track    : Feel Special
# audio    : https://p.scdn.co/mp3-preview/551a68c6cc034e13c2e86384990534288fdce500?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b273936fec46d7625f30936959dc
#
# track    : YES or YES
# audio    : https://p.scdn.co/mp3-preview/882de4f6fdba2d2a81b3f6dbb5c2f58c5d7a7c31?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b2738c66dd4692d695f414725131

# %%
def get_playlists_by_genre(genre, limit):
    results = sp.search(genre, limit=limit, type='playlist')
    return results['playlists']['items']

def print_playlist_info(playlists):
    for playlist in playlists:
        p_name = playlist['name']
        p_id = playlist['id']
        p_tot_tracks = playlist['tracks']['total']
        print(f'{p_name} (Playlist ID:{p_id}) : {p_tot_tracks} tracks')
        #return p_tot_tracks

def get_playlist_tracks(playlist_id):
    playlist_tracks = sp.playlist_tracks('37i9dQZF1DX70RN3TfWWJh')
    p_artist_name = playlist_tracks['items'][i]['track']['artists'][0]['name']
    p_track_name = playlist_tracks['items'][i]['track']['name']
    p_track_id = playlist_tracks['items'][i]['track']['id']
    return print(f'{p_track_name} - {p_artist_name} - {p_track_id}')

playlists = get_playlists_by_genre('workout', 10)
print_playlist_info(playlists)
# Out:
# Workout (Playlist ID:37i9dQZF1DX70RN3TfWWJh) : 100 tracks
# Workout Mix (Playlist ID:37i9dQZF1EIfGSSqagkuBB) : 50 tracks
# workout 💦 (Playlist ID:4ETxM0kkS3RMPveAijToRh) : 285 tracks
# Power Workout (Playlist ID:37i9dQZF1DWUVpAXiEPK8P) : 50 tracks
# Workout Music Hyped Up (Playlist ID:50GRZhhlglsNaWlN6u3hQ8) : 107 tracks
# workout (Playlist ID:2HOsjhKz9vrDeLLTUYRxn8) : 64 tracks
# Rap Workout (Playlist ID:37i9dQZF1DX76t638V6CA8) : 59 tracks
# Workout Playlist 💪🏽 Hot Girl Workout Songs So He Regrets It / Workout Music / Gym Playlist/ Gym Music (Playlist ID:0OxRbscW9gq3FzENFlUPes) : 291 tracks
# Workout Beats (Playlist ID:37i9dQZF1DWUSyphfcc6aL) : 70 tracks
# Throwback Workout (Playlist ID:37i9dQZF1DX8CwbNGNKurt) : 75 tracks

# %%
def get_user_playlist_tracks(username,playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
playlist_tracks = sp.playlist_tracks('37i9dQZF1DX70RN3TfWWJh')
p_artist_name = playlist_tracks['items'][0]['track']['artists'][0]['name']
p_track_name = playlist_tracks['items'][0]['track']['name']
p_track_id = playlist_tracks['items'][0]['track']['id']
print(f'Artist Name: {p_artist_name}')
print(f'Track Name: {p_track_name}')
print(f'Track Id: {p_track_id}')
print('='*40)
# Out:
# Artist Name: Rina Sawayama
# Track Name: This Hell
# Track Id: 6A6yKpsgFr4gIKd7gsfHhm
# ========================================

# %%
def get_playlist_tracks(playlist_id, tot_tracks):
    track_list = []
    for i in range(tot_tracks):
        playlist_tracks = sp.playlist_tracks('37i9dQZF1DX70RN3TfWWJh')
        p_artist_name = playlist_tracks['items'][i]['track']['artists'][0]['name']
        p_track_name = playlist_tracks['items'][i]['track']['name']
        p_track_id = playlist_tracks['items'][i]['track']['id']
        track_list.append(p_track_id)
    return track_list

# %%
get_playlist_tracks('37i9dQZF1DX70RN3TfWWJh', 100)
# Out:
# ['6A6yKpsgFr4gIKd7gsfHhm',
#  '2SLwbpExuoBDZBpjfefCtV',
#  '1qEmFfgcLObUfQm0j1W2CK',
#  '3DarAbFujv6eYNliUTyqtz',
#  '7mFj0LlWtEJaEigguaWqYh',
#  '3QyoC6OvQUmpQwQZ18iaTs',
#  '7BoVAJ0HuKcBBRmUGlzX6o',
#  '2xXPVOKw75Ouju8Qu4SdIA',
#  '0prbvDtiY8FrZKEj8LF4Rs',
#  '1QxIFMs4M8qd5cbJJu80v4',
#  '2cc8Sw1OnCuA5bV8nqWqpE',
#  '5LYMamLv12UPbemOaTPyeV',
#  '5f8XRR4GHscONHDFK6XyUp',
#  '19VgR6RNUxPlZdQm08CZIs',
#  '7jvCeWOSnJs2N3spqobWnO',
#  '0kJxW8nJoFDqriiIh1u6HU',
#  '4Dvkj6JhhA12EX05fT7y2e',
#  '1ZxxfkeHKl0YKcPjKzeS4c',
#  '5rW7qTn83sCKtqBoneJs63',
#  '1ZVzr825BOBAyGZoQqCSRg',
#  '2KukL7UlQ8TdvpaA7bY3ZJ',
#  '1BXAyGazbybUVNQ0VmGsdl',
#  '14Ms2pa4WOCjb8zkqdJ9JG',
#  '2WTHLEVjfefbGoW7F3dXIg',
#  '1BSMpVGWs3v5BZKnAQziAc',
#  '6KfoDhO4XUWSbnyKjNp9c4',
#  '15ibpzLxaUqycubbAfPFpe',
#  '4h4QlmocP3IuwYEj2j14p8',
#  '02MWAaffLxlfxAUY7c5dvx',
#  '1IHWl5LamUGEuP4ozKQSXZ',
#  '4h9wh7iOZ0GGn8QVp4RAOB',
#  '4ewmHD3aRBmLyTsbGreNLw',
#  '3Ca24oa8tofPtGYuULHXHI',
#  '35COLcFjvONwVv6jkG23gI',
#  '7l7SKt5BsDiiS6CjtaW1fO',
#  '4NjTrZ2IQeWnIbzyY2SOfz',
#  '3YY9Yu1JsgVfF1lOXEenq9',
#  '6LA7WgwRca4bYg7Ip50dqN',
#  '0ZXdzaT1k688dkpNeEgQiV',
#  '3RauEVgRgj1IuWdJ9fDs70',
#  '4WIaDYUIlXsHi4yMF596aI',
#  '25gacl0dFF9HTclx7Ug7xC',
#  '0H8Tclo4x4kbZruQtZFNSX',
#  '1cK0KFqlnTQC6oqPh3CXt2',
#  '6Zu3aw7FfjAF9WA0fA81Oq',
#  '4FZFNT9WFjVUwLEXFgC1eQ',
#  '1MfbWqsh6HxRxXd6pJwnXy',
#  '31sSFHIe4NaxltVFOEIcTa',
#  '4L6ihclQPu1hqP9r3WNJjQ',
#  '2ZzHR2sOKAOKyN8efCa69E',
#  '1CuGuLSXI9k85Ppxw908yP',
#  '7aonAWn0J0AJ47ZU9WHCXC',
#  '0VO8gYVDSwM1Qdd2GsMoYK',
#  '2bJgUPmlG2o6A0qfZJgkdh',
#  '0vQYe6g8bNbdUKnUnXdQQV',
#  '7CTdh15dTO5HqoeqRPHFha',
#  '0e8nrvls4Qqv5Rfa2UhqmO',
#  '3Kkjo3cT83cw09VJyrLNwX',
#  '7l9IqDtVWJurTvkQHq1BGh',
#  '6OFxiLfnMwOodCdV7x2yXC',
#  '6Skh3CBum0pZw9TOr7FQnX',
#  '7weX6syqklVQocpVVmDNwI',
#  '5XPo15e5ICs6NvSMn44pTF',
#  '4ZtFanR9U6ndgddUvNcjcG',
#  '4TZ2Ub8bZh4LTs06eANDXa',
#  '5Z9KJZvQzH6PFmb8SNkxuk',
#  '0Dtv5iaqPWtftabQfjBvxh',
#  '1r8ZCjfrQxoy2wVaBUbpwg',
#  '2UN1L1asI3uKQCijznnz8Z',
#  '7reG3QYhefsJNpcVJq4BZr',
#  '1J9ekSUHGCaWKBdmeEWPJZ',
#  '4FYbo4yQzu3hGkj2Ix4ucW',
#  '7ElC7VjUNl3oJ20Q5OpEh9',
#  '0rIAC4PXANcKmitJfoqmVm',
#  '6I3mqTwhRpn34SLVafSH7G',
#  '4qu63nuBpdn0qHUHuObEj1',
#  '3sYZo4HrHX8tkul5FhUpVo',
#  '42TrdbXsmLybxUGJczYbrJ',
#  '6xw8ld1ztoCKifwTN6uGDq',
#  '5HCyWlXZPP0y6Gqq8TgA20',
#  '0sb8ClU3CLoNblxkpmOKzA',
#  '3wrWJ4cpGWSL2JZieVXhdR',
#  '3XYRV7ZSHqIRDG87DKTtry',
#  '1xyUCr7dIJYaUaaiDf4Q1L',
#  '5nhW8I46uDE5sc5ouEbzao',
#  '6Ql7rNuoP90aIdgwQkPYBP',
#  '1797zYiX4cKosMH836X9Gt',
#  '4JUPEh2DVSXFGExu4Uxevz',
#  '3FeVmId7tL5YN8B7R3imoM',
#  '2iHsdUnmKGIuc9oRE3DfgJ',
#  '1A3maiVKkyHkkfkc7KKcOB',
#  '7BoobGhD4x5K96Me0hqC8Q',
#  '2Oycxb8QbPkpHTo8ZrmG0B',
#  '7dSZ6zGTQx66c2GF91xCrb',
#  '4RAR8g8fZNB106ezUurnE0',
#  '1RSBK5VWdjPjHEmRhAkS4Q',
#  '73QyyUMMvtNELmULI4FOsp',
#  '4i2qxFEVVUi8yOYoxB8TCX',
#  '2wVQcA1YCuGL6EW0QbgVoV',
#  '0z8hI3OPS8ADPWtoCjjLl6']

# %%
sp.track('6A6yKpsgFr4gIKd7gsfHhm')['name']
# Out:
# 'This Hell'

# %%
playlists = get_playlists_by_genre('workout', 10)
print_playlist_info(playlists)
# Out:
# Workout (Playlist ID:37i9dQZF1DX70RN3TfWWJh) : 100 tracks
# Workout Mix (Playlist ID:37i9dQZF1EIfGSSqagkuBB) : 50 tracks
# workout 💦 (Playlist ID:4ETxM0kkS3RMPveAijToRh) : 285 tracks
# Power Workout (Playlist ID:37i9dQZF1DWUVpAXiEPK8P) : 50 tracks
# Workout Music Hyped Up (Playlist ID:50GRZhhlglsNaWlN6u3hQ8) : 107 tracks
# workout (Playlist ID:2HOsjhKz9vrDeLLTUYRxn8) : 64 tracks
# Rap Workout (Playlist ID:37i9dQZF1DX76t638V6CA8) : 59 tracks
# Workout Playlist 💪🏽 Hot Girl Workout Songs So He Regrets It / Workout Music / Gym Playlist/ Gym Music (Playlist ID:0OxRbscW9gq3FzENFlUPes) : 291 tracks
# Workout Beats (Playlist ID:37i9dQZF1DWUSyphfcc6aL) : 70 tracks
# Throwback Workout (Playlist ID:37i9dQZF1DX8CwbNGNKurt) : 75 tracks
