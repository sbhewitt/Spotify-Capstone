# %% [markdown]
# ## Capstone

# %%
from __future__ import print_function    # (at top of module)
from spotipy.oauth2 import SpotifyClientCredentials, SpotifyOAuth
import json
import spotipy
import time
import timeit
import sys
import argparse
import logging
import pprint
import pandas as pd
import numpy as np

# %%
cid = 
secret = 
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 
sp = spotipy.Spotify(auth_manager = spotipy.SpotifyOAuth(client_id = cid, client_secret = secret,
                            redirect_uri = "http://localhost:8888/callback",
                            scope = "user-library-read",
                            open_browser=False))

# %%
# recent saved tracks
results = sp.current_user_saved_tracks()
for idx, item in enumerate(results['items']):
    track = item['track']
    #print(idx, track['artists'][0]['name'], " – ", track['name'], " – ", track['explicit'], " – ", track['artists'])
    #print(idx, track['artists'][0]['name'], " – ", track['name'],  " – ", track['artists'][0]['uri'],  " – ", track['popularity'])
    print(idx, track['artists'][0]['name'], " – ", track['name'],  " – ", track['id'],  " – ", track['popularity'])
# Out:
# 0 1nonly  –  Stay With Me  –  2WYs5LxOZfEyURXu7V0O1a  –  81
# 1 Machine Girl  –  Ghost  –  4orMsymF399H3xKBc0AIhx  –  60
# 2 Beyoncé  –  BREAK MY SOUL  –  40KCN2nYImUounlfO5Cdzn  –  74
# 3 TOKiMONSTA  –  Loved By U  –  1SldN7GTd0ADTjspv96wCl  –  60
# 4 City Girl  –  HEARTBREAKER CLUB  –  6Rpk7fmD3TWTBfJnIpjiZp  –  52
# 5 slowthai  –  Doorman  –  6bTAz3pg5ywBeZHCQoleJB  –  62
# 6 REI AMI  –  do it right (feat. Aminé)  –  6bKM56cyoz8kjiK7QKQ87i  –  42
# 7 YDE  –  People Can Change  –  0dtysSew3Hb1o8e4h1IPSz  –  44
# 8 Joyce Wrice  –  That's On You - Japanese Remix  –  56Vy5lJUoHTI90MMnyI2CM  –  46
# 9 Porter Robinson  –  Everything Goes On  –  3WBRfkOozHEsG0hbrBzwlm  –  79
# 10 Tobe Nwigwe  –  ROUND HERE (PART ONE)  –  3rGkm51Yn7ynxGmGcNC5De  –  52
# 11 stoop lee  –  SWEETBABYRAE  –  6MNTsxexrJEsDW4fSEAiXS  –  44
# 12 MYRNE  –  What Can I Do  –  4SH4MuHj0BtOTddqvPFhxI  –  0
# 13 Japanese Breakfast  –  Nobody Sees Me Like You Do  –  3vGsonmcc2Y7x8BZYKnjhi  –  47
# ...

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2022', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
track_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_df.shape)
track_df#.sort_values(by = 'popularity', ascending = False)
# Out:
# (1000, 4)
#                     artist_name                     track_name  \
# 0                     Bad Bunny                Me Porto Bonito
# 1                     Ish Kevin                 My Year (2022)
# 2             Machine Gun Kelly  drug dealer (feat. Lil Wayne)
# 3                 Years & Years         Desire - Gryffin Remix
# 4                          Joji                  Glimpse of Us
# ..                          ...                            ...
# 995               Ferreck James                          Years
# 996  YoungBoy Never Broke Again                          Proof
# 997               Ferreck James                          Years
# 998  YoungBoy Never Broke Again               Fuck Da Industry
# 999               Ferreck James                          Years
#
#                    track_id  popularity
# 0    6Sq7ltF9Qa7SNFBsV5Cogx          99
# 1    4eHkG6yWQ4pD0zqVkV0R5a          21
# 2    4Gm1VAxKdLS9aL7bkbZZyr          68
# ...

# %%
track_df['track_id']
# Out:
# 0      4h4QlmocP3IuwYEj2j14p8
# 1      7h7yPyss4MIBVPXVeF83vg
# 2      3cBsEDNhFI9E82vPj3kvi3
# 3      3oyc1mIdCBGaU55wX7otqM
# 4      2BcMwX1MPV6ZHP4tUT9uq6
#                 ...
# 995    4bXn4UFgIH0XXhVhaavLma
# 996    3Ewve2NtuSLBVqtqjY948y
# 997    3PKtIgJFwQB4jjIFWjdhba
# 998    4jRY7o8U8MGETLeTjV2qJj
# 999    7F9aDyXyIqntDtuAAjhZcV
# Name: track_id, Length: 1000, dtype: object

# %%
sp.audio_features('5zIXVqJifYPQrom15l3eI3')[0]
# Out:
# {'danceability': 0.558,
#  'energy': 0.838,
#  'key': 7,
#  'loudness': -6.479,
#  'mode': 1,
#  'speechiness': 0.0417,
#  'acousticness': 0.0612,
#  'instrumentalness': 0.00182,
#  'liveness': 0.309,
#  'valence': 0.778,
#  'tempo': 119.089,
#  'type': 'audio_features',
#  'id': '5zIXVqJifYPQrom15l3eI3',
#  'uri': 'spotify:track:5zIXVqJifYPQrom15l3eI3',
#  'track_href': 'https://api.spotify.com/v1/tracks/5zIXVqJifYPQrom15l3eI3',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5zIXVqJifYPQrom15l3eI3',
#  'duration_ms': 191107,
#  'time_signature': 4}

# %%
sp.audio_features('0qM0FYeAgpZaWhuiGgSioF')
# Out:
# [{'danceability': 0.645,
#   'energy': 0.71,
#   'key': 11,
#   'loudness': -8.342,
#   'mode': 0,
#   'speechiness': 0.473,
#   'acousticness': 0.29,
#   'instrumentalness': 0,
#   'liveness': 0.524,
#   'valence': 0.801,
#   'tempo': 134.27,
#   'type': 'audio_features',
#   'id': '0qM0FYeAgpZaWhuiGgSioF',
#   'uri': 'spotify:track:0qM0FYeAgpZaWhuiGgSioF',
#   'track_href': 'https://api.spotify.com/v1/tracks/0qM0FYeAgpZaWhuiGgSioF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0qM0FYeAgpZaWhuiGgSioF',
#   'duration_ms': 51445,
#   'time_signature': 4}]

# %% [markdown]
# ---
# Function to get tracks by year. Running into API error where some songs in specific years are missing audio features

# %%
def get_tracks_to_csv(year):
    artist_name = []
    track_name = []
    popularity = []
    track_id = []
    for i in range(0,1000,50):
        track_results = sp.search(q=f'year:{year}', type='track', limit=50,offset=i)
        for i, t in enumerate(track_results['tracks']['items']):
            artist_name.append(t['artists'][0]['name'])
            track_name.append(t['name'])
            track_id.append(t['id'])
            popularity.append(t['popularity'])
    track_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})


    dict_list=[]
    for track in track_df['track_id']:
        dict_list.append(sp.audio_features(track)[0])
    audio_feat_df = pd.DataFrame(dict_list)

    merged_df = track_df.merge(audio_feat_df, left_on='track_id', right_on='id')
    merged_df = merged_df.drop_duplicates(subset = ['track_id'], keep = 'last')
    merged_df.to_csv(f'./tracks_{year}.csv')
    return

# %% [markdown]
# ## 2021 tracks
# Note: Track ID **0qM0FYeAgpZaWhuiGgSioF** had no audio features on 8/8, but suddenly did on 8/9

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2021', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
track_2021_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_df.shape)
track_2021_df
# Out:
# (1000, 4)
#                           artist_name  \
# 0                         Nicky Youre
# 1                           Dj Biffen
# 2                       Morgan Wallen
# 3    Elvis Costello & The Attractions
# 4                               Drake
# ..                                ...
# 995                              K120
# 996                             Nic D
# 997                           Tutxtut
# 998                           JELEEL!
# 999                        Matt Monro
#
#                                             track_name  \
# 0                                              Sunroof
# 1    Merry Christmas and Happy New Year 2021 - Radi...
# 2                                        Wasted On You
# 3                           Pump It Up - 2021 Remaster
# 4          Knife Talk (with 21 Savage ft. Project Pat)
# ..                                                 ...
# 995     It's Christmas, You Are 13 Years Old and Happy
# ...

# %%
dict_list_2021=[]
for track in track_2021_df['track_id']:
    dict_list_2021.append(sp.audio_features(track)[0])
audio_feat_2021_df = pd.DataFrame(dict_list_2021)
audio_feat_2021_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.768   0.714   10    -5.110     1       0.0401       0.35200
# 1           0.887   0.633    8   -10.453     1       0.0660       0.06290
# 2           0.505   0.657   11    -5.240     0       0.0318       0.37300
# 3           0.645   0.809   11    -6.120     1       0.0385       0.00921
# 4           0.849   0.424    5    -9.579     0       0.3240       0.06350
# ..            ...     ...  ...       ...   ...          ...           ...
# 995         0.676   0.555    7   -12.511     1       0.0489       0.03030
# 996         0.914   0.572    0    -6.606     1       0.0359       0.12000
# 997         0.818   0.681    7   -10.665     0       0.4760       0.15500
# 998         0.700   0.792    6    -5.280     1       0.0459       0.00128
# 999         0.531   0.385    7   -12.718     1       0.0545       0.53000
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
merged_2021_df = track_2021_df.merge(audio_feat_2021_df, left_on='track_id', right_on='id')
merged_2021_df = merged_2021_df.drop_duplicates(subset = ['track_id'], keep = 'last')
merged_2021_df
# Out:
#                            artist_name  \
# 0                          Nicky Youre
# 1                            Dj Biffen
# 2                        Morgan Wallen
# 3     Elvis Costello & The Attractions
# 4                                Drake
# ...                                ...
# 1073                              K120
# 1074                             Nic D
# 1075                           Tutxtut
# 1076                           JELEEL!
# 1077                        Matt Monro
#
#                                              track_name  \
# 0                                               Sunroof
# 1     Merry Christmas and Happy New Year 2021 - Radi...
# 2                                         Wasted On You
# 3                            Pump It Up - 2021 Remaster
# 4           Knife Talk (with 21 Savage ft. Project Pat)
# ...                                                 ...
# 1073     It's Christmas, You Are 13 Years Old and Happy
# ...

# %%
merged_2021_df.to_csv('./tracks_2021.csv')

# %% [markdown]
# # 2020 tracks

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2020', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
track_2020_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_2020_df.shape)
track_2020_df
# Out:
# (1000, 4)
#        artist_name            track_name                track_id  popularity
# 0       The Weeknd       Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b          91
# 1          Hammock   Longest Year (2020)  0MlkZnfwsjwHHSfn07N8ao          18
# 2    Glass Animals            Heat Waves  3USxtqRwSYz57Ewm6wWRMp          85
# 3      Tame Impala  Alter Ego - 2020 Mix  457sndKohlwTU6dW6amBMU          44
# 4       Elley Duhé   MIDDLE OF THE NIGHT  58HvfVOeJY7lUuCqF0m3ly          92
# ..             ...                   ...                     ...         ...
# 995        Q Murda                  2020  0hl6UkiVJ5LHJwsqE24fej           3
# 996     Zach Bryan          Let You Down  1HMFdKHDiHY0qmqdVH710d          64
# 997          Swørn            Keep Going  5wxxsUijre15T715mScE7i           9
# 998   Taylor Swift                august  6nK2pIKFcRc5frrZKHgsiT          71
# 999      F.E.A.T.S                  2020  3ghQqY1LpcQT0TqXHMYsCC          10
#
# [1000 rows x 4 columns]

# %%
dict_list_2020=[]
for track in track_2020_df['track_id']:
    dict_list_2020.append(sp.audio_features(track)[0])
audio_feat_2020_df = pd.DataFrame(dict_list_2020)
audio_feat_2020_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.5140   0.730    1    -5.934     1       0.0598       0.00146
# 1          0.0705   0.286    2   -14.865     1       0.0444       0.68500
# 2          0.7610   0.525   11    -6.900     1       0.0944       0.44000
# 3          0.4080   0.903    0    -2.924     1       0.0561       0.00256
# 4          0.4100   0.611    4    -8.271     0       0.0467       0.02280
# ..            ...     ...  ...       ...   ...          ...           ...
# 995        0.6320   0.444    4   -13.589     1       0.7030       0.18500
# 996        0.5150   0.457    2    -4.786     1       0.0277       0.39000
# 997        0.7570   0.336    0   -10.648     0       0.0880       0.78600
# 998        0.3870   0.634    5    -9.222     1       0.0363       0.55300
# 999        0.7010   0.645    8    -6.937     0       0.1360       0.19000
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
merged_2020_df = track_2020_df.merge(audio_feat_2020_df, left_on='track_id', right_on='id')
merged_2020_df
# Out:
#         artist_name            track_name                track_id  popularity  \
# 0        The Weeknd       Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b          91
# 1           Hammock   Longest Year (2020)  0MlkZnfwsjwHHSfn07N8ao          18
# 2     Glass Animals            Heat Waves  3USxtqRwSYz57Ewm6wWRMp          85
# 3       Tame Impala  Alter Ego - 2020 Mix  457sndKohlwTU6dW6amBMU          44
# 4        Elley Duhé   MIDDLE OF THE NIGHT  58HvfVOeJY7lUuCqF0m3ly          92
# ...             ...                   ...                     ...         ...
# 1063        Q Murda                  2020  0hl6UkiVJ5LHJwsqE24fej           3
# 1064     Zach Bryan          Let You Down  1HMFdKHDiHY0qmqdVH710d          64
# 1065          Swørn            Keep Going  5wxxsUijre15T715mScE7i           9
# 1066   Taylor Swift                august  6nK2pIKFcRc5frrZKHgsiT          71
# 1067      F.E.A.T.S                  2020  3ghQqY1LpcQT0TqXHMYsCC          10
#
# ...

# %%
(merged_2020_df['track_id'] == merged_2020_df['id']).value_counts()
# Out:
# True    1068
# dtype: int64

# %%
merged_2020_df = merged_2020_df.drop_duplicates(subset = ['track_id'], keep = 'last')
merged_2020_df
# Out:
#         artist_name            track_name                track_id  popularity  \
# 0        The Weeknd       Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b          91
# 1           Hammock   Longest Year (2020)  0MlkZnfwsjwHHSfn07N8ao          18
# 2     Glass Animals            Heat Waves  3USxtqRwSYz57Ewm6wWRMp          85
# 3       Tame Impala  Alter Ego - 2020 Mix  457sndKohlwTU6dW6amBMU          44
# 4        Elley Duhé   MIDDLE OF THE NIGHT  58HvfVOeJY7lUuCqF0m3ly          92
# ...             ...                   ...                     ...         ...
# 1063        Q Murda                  2020  0hl6UkiVJ5LHJwsqE24fej           3
# 1064     Zach Bryan          Let You Down  1HMFdKHDiHY0qmqdVH710d          64
# 1065          Swørn            Keep Going  5wxxsUijre15T715mScE7i           9
# 1066   Taylor Swift                august  6nK2pIKFcRc5frrZKHgsiT          71
# 1067      F.E.A.T.S                  2020  3ghQqY1LpcQT0TqXHMYsCC          10
#
# ...

# %%
merged_2020_df.to_csv('./tracks_2020.csv')

# %% [markdown]
# # 2019 Tracks

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2019', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
track_2019_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})
print(track_2019_df.shape)
track_2019_df
# Out:
# (1000, 4)
#            artist_name                                         track_name  \
# 0            Baby Keem                                             HONEST
# 1           Otmar Eros                                  Year 2016:, Pt. 4
# 2          Post Malone                                            Circles
# 3        Calvin Harris                                           One Kiss
# 4         Harry Styles                                   Watermelon Sugar
# ..                 ...                                                ...
# 995    Quality Control  Leave Em Alone (Layton Greene, Lil Baby feat. ...
# 996             Yawiar                                               2020
# 997       Kristen Bell                           Some Things Never Change
# 998        Bad Company                     Rhythm Machine - 2019 Remaster
# 999  Sabrina Carpenter                                      Looking at Me
#
#                    track_id  popularity
# ...

# %%
dict_list_2019=[]
for track in track_2019_df['track_id']:
    dict_list_2019.append(sp.audio_features(track)[0])
audio_feat_2019_df = pd.DataFrame(dict_list_2019)
audio_feat_2019_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.676   0.536    2    -8.790     1       0.0432       0.40300
# 1           0.241   0.064    5   -24.272     1       0.0602       0.99400
# 2           0.695   0.762    0    -3.497     1       0.0395       0.19200
# 3           0.753   0.852    9    -4.028     0       0.1380       0.03190
# 4           0.548   0.816    0    -4.209     1       0.0465       0.12200
# ..            ...     ...  ...       ...   ...          ...           ...
# 995         0.760   0.755    6    -4.735     0       0.1900       0.01630
# 996         0.760   0.767    2    -6.322     1       0.2580       0.64100
# 997         0.566   0.543    5    -4.485     1       0.0314       0.61300
# 998         0.700   0.679    7    -6.864     1       0.0297       0.05010
# 999         0.681   0.798    2    -4.367     1       0.0375       0.00398
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
merged_2019_df = track_2019_df.merge(audio_feat_2019_df, left_on='track_id', right_on='id')
merged_2019_df = merged_2019_df.drop_duplicates(subset = ['track_id'], keep = 'last')
merged_2019_df
# Out:
#             artist_name                                         track_name  \
# 0             Baby Keem                                             HONEST
# 1            Otmar Eros                                  Year 2016:, Pt. 4
# 2           Post Malone                                            Circles
# 3         Calvin Harris                                           One Kiss
# 4          Harry Styles                                   Watermelon Sugar
# ...                 ...                                                ...
# 1043    Quality Control  Leave Em Alone (Layton Greene, Lil Baby feat. ...
# 1044             Yawiar                                               2020
# 1045       Kristen Bell                           Some Things Never Change
# 1046        Bad Company                     Rhythm Machine - 2019 Remaster
# 1047  Sabrina Carpenter                                      Looking at Me
#
# ...

# %%
merged_2019_df.to_csv('./tracks_2019.csv')

# %% [markdown]
# # 2022 Tracks

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2022', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
track_2022_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})


dict_list_2022=[]
for track in track_2022_df['track_id']:
    dict_list_2022.append(sp.audio_features(track)[0])
audio_feat_2022_df = pd.DataFrame(dict_list_2022)

merged_2022_df = track_2022_df.merge(audio_feat_2022_df, left_on='track_id', right_on='id')
merged_2022_df = merged_2022_df.drop_duplicates(subset = ['track_id'], keep = 'last')
merged_2022_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [235], in <cell line: 18>()
#      16 for track in track_2022_df['track_id']:
#      17     dict_list_2022.append(sp.audio_features(track)[0])
# ---> 18 audio_feat_2022_df = pd.DataFrame(dict_list_2022)
#      20 merged_2022_df = track_2022_df.merge(audio_feat_2022_df, left_on='track_id', right_on='id')
#      21 merged_2022_df = merged_2022_df.drop_duplicates(subset = ['track_id'], keep = 'last')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:721, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     716     if columns is not None:
#     717         # error: Argument 1 to "ensure_index" has incompatible type
#     718         # "Collection[Any]"; expected "Union[Union[Union[ExtensionArray,
#     719         # ndarray], Index, Series], Sequence[Any]]"
# ...

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2015', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
track_2015_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})


dict_list_2015=[]
for track in track_2015_df['track_id']:
    dict_list_2015.append(sp.audio_features(track)[0])
audio_feat_2015_df = pd.DataFrame(dict_list_2015)

merged_2015_df = track_2015_df.merge(audio_feat_2015_df, left_on='track_id', right_on='id')
merged_2015_df = merged_2015_df.drop_duplicates(subset = ['track_id'], keep = 'last')
merged_2015_df
# Out:
#               artist_name                    track_name  \
# 0                  WILLOW                Wait a Minute!
# 1       Schoolgirl Byebye                     Year,2015
# 2              The Weeknd                     The Hills
# 3             Iron Maiden  Wasted Years - 2015 Remaster
# 4         Chris Stapleton             Tennessee Whiskey
# ...                   ...                           ...
# 1129          Miles Davis       Splatch - 2015 Remaster
# 1130  Hot Flash Heat Wave                   Gutter Girl
# 1131        Pop Hits 2015               American Oxygen
# 1132            Dreamgirl                  Teenage Blue
# 1133          Miles Davis        Tomaas - 2015 Remaster
#
#                     track_id  popularity  danceability  energy  key  loudness  \
# 0     0y60itmpH0aPKsFiGxmtnh          87         0.764  0.7050    3    -5.279
# 1     0UsmyJDsst2xhX1ZiFF3JW          23         0.314  0.0855    9   -15.775
# ...

# %%
merged_2015_df.to_csv('./tracks_2015.csv')

# %% [markdown]
# # 2014 Tracks

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2014', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
track_2014_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})


dict_list_2014=[]
for track in track_2014_df['track_id']:
    dict_list_2014.append(sp.audio_features(track)[0])
audio_feat_2014_df = pd.DataFrame(dict_list_2014)

merged_2014_df = track_2014_df.merge(audio_feat_2014_df, left_on='track_id', right_on='id')
merged_2014_df = merged_2014_df.drop_duplicates(subset = ['track_id'], keep = 'last')
merged_2014_df
# Out:
#           artist_name                                         track_name  \
# 0             J. Cole                                     No Role Modelz
# 1       Anthem Lights  K-Love Fan Awards: Songs of the Year (2014 Mas...
# 2         The Walters                                      I Love You So
# 3        Steve Harley  Make Me Smile (Come up and See Me) - 2014 Rema...
# 4             J. Cole                                         Wet Dreamz
# ...               ...                                                ...
# 1103  Penelope Shorty                                             Royals
# 1104      OneRepublic                                         Feel Again
# 1105  Michael Stanley                              My Side of the Moment
# 1106    Justin Bieber                                   All That Matters
# 1107              Otc  The Year of the Cat - Alex Gaudino & Jason Roo...
#
#                     track_id  popularity  danceability  energy  key  loudness  \
# ...

# %%
merged_2014_df.to_csv('./tracks_2014.csv')

# %% [markdown]
# # 2013 Tracks

# %%
artist_name = []
track_name = []
popularity = []
track_id = []
for i in range(0,1000,50):
    track_results = sp.search(q='year:2013', type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        popularity.append(t['popularity'])
track_2013_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'popularity' : popularity})


dict_list_2013=[]
for track in track_2013_df['track_id']:
    dict_list_2013.append(sp.audio_features(track)[0])
audio_feat_2013_df = pd.DataFrame(dict_list_2013)

merged_2013_df = track_2013_df.merge(audio_feat_2013_df, left_on='track_id', right_on='id')
merged_2013_df = merged_2013_df.drop_duplicates(subset = ['track_id'], keep = 'last')
merged_2013_df
# Out:
#                 artist_name  \
# 0         The Neighbourhood
# 1                 Riff Raff
# 2                      MKTO
# 3                Kanye West
# 4                    Eagles
# ...                     ...
# 1087             The Pogues
# 1088  Johann Sebastian Bach
# 1089                 Maejor
# 1090               Sneijder
# 1091  Johann Sebastian Bach
#
#                                              track_name  \
# 0                                       Sweater Weather
# 1                               Rookie of the Year 2013
# 2                                               Classic
# 3                                               Bound 2
# 4        Please Come Home for Christmas - 2013 Remaster
# ...                                                 ...
# 1087                       Down All the Days - 2013 Mix
# 1088  Das Wohltemperierte Klavier: Book 1, BWV 846-8...
# 1089                                              Lolly
# ...

# %%
merged_2013_df.to_csv('./tracks_2013.csv')

# %%
get_tracks_to_csv(2012)

# %%
start = timeit.default_timer()

results = sp.search(q='twice', limit=20)
for idx, track in enumerate(results['tracks']['items']):
    print(idx, track['name'])

stop = timeit.default_timer()
print ('Time to run this code (in seconds):', stop - start)
# Out:
# 0 Twice As Hard
# 1 Break Up Twice
# 2 The Feels
# 3 The Feels
# 4 FANCY
# 5 You Only Live Twice (with Lil Wayne & Rick Ross)
# 6 POP!
# 7 I CAN'T STOP ME
# 8 Devil Always Made Me Think Twice
# 9 Alcohol-Free
# 10 Twice
# 11 Once Bitten Twice Shy
# 12 TT
# 13 What is Love
# 14 Likey
# 15 Twice
# 16 Feel Special
# 17 SCIENTIST
# 18 CHEER UP
# 19 CRY FOR ME
# Time to run this code (in seconds): 0.12898089999998774

# %%
# users playlists
sp = spotipy.Spotify(auth_manager = spotipy.SpotifyOAuth(client_id = cid, client_secret = secret,
                            redirect_uri = "http://localhost:8888/callback",
                            scope = "playlist-read-private",
                            open_browser=False))
results = sp.current_user_playlists(limit=50)
for i, item in enumerate(results['items']):
    print("%d %s %s" % (i, item['name'], item['id']))
# Out:
# 0 Share whatever you like 7f7oviGdx9TPEVpBpm2sQR
# 1 TWICE 4TH WORLD TOUR 'Ⅲ' 3iA20ztniCf3PDFwGpwWAV
# 2 When We Were Young Fest Playlist 5j0A0VY64GXN2OR1ugYacW
# 3 AUDREY NUNA Mix 37i9dQZF1EIV7DyQUiPGPj
# 4 Porter Robinson Mix 37i9dQZF1EIVekANNCHutz
# 5 Japanese Breakfast Mix 37i9dQZF1EIWiVFFbMUz7d
# 6 Megan Thee Stallion and I 4uOrVYljLRnuiGioNVHVLU
# 7 porter robinson : cherished music 1H163taKSeBERTtCu3R7bp
# 8 Jasmine 37i9dQZF1DX5IOhx43PGIa
# 9 music from DAVE 23qwzp0yfy4GMxO34YWcR4
# 10 NKOH Warm Ups 6XGujD8cSfKGqrJrgoKIC5
# 11 The 200 Best Songs of the 2010s 2ua9P1PJZ8vNU1ZOZq6tqe
# 12 This Is Yung Bae 37i9dQZF1DZ06evO1JQKJZ
# 13 Hula/Tahitian Basics 6knU9lcnx4vnynEP6QpdoH
# 14 SLORP 3pqOXRMNPdF9vpdkxhbNyc
# 15 ham 2ValR1wNUOoy0BowzsExiV
# 16 悲しい音楽 33Pb8m7dzLyCzUR3UBeAwN
# 17 SAD WINTER BOY 3OktKQC1OLJ5QFgTErrI6L
# 18 Favorites 7hMBUPSLUuZvynHuCGKIfb
# 19 Who hurt you??? 4j7N0oh95PtMspcN3I07sc
# 20 Songs That Get Drunk White Girls Excited 4FO2WXjS922s0RheaTYPZK
# ...

# %%
# users top songs, (short term, mid term, long term)
sp = spotipy.Spotify(auth_manager = spotipy.SpotifyOAuth(client_id = cid, client_secret = secret,
                            redirect_uri = "http://localhost:8888/callback",
                            scope = "user-top-read",
                            open_browser=False))

ranges = ['short_term', 'medium_term', 'long_term']

for sp_range in ranges:
    print("range:", sp_range)
    results = sp.current_user_top_tracks(time_range=sp_range, limit=50)
    for i, item in enumerate(results['items']):
        print(i, item['name'], '-', item['artists'][0]['name'], '-',  item['id'])
    print()
    #print(idx, track['artists'][0]['name'], " – ", track['name'],  " – ", track['id'],  " – ", track['popularity'])
# Out:
# INFO:spotipy.oauth2:User authentication requires interaction with your web browser. Once you enter your credentials and give authorization, you will be redirected to a url.  Paste that url you were directed to to complete the authorization.
# range: short_term
# Go to the following URL: https://accounts.spotify.com/authorize?client_id=0f298608fe46432daff4e6304d5607bd&response_type=code&redirect_uri=http%3A%2F%2Flocalhost%3A8888%2Fcallback&scope=user-top-read
# Enter the URL you were redirected to:  http://localhost:8888/callback?code=AQCsYKTsiiShsDW5WZ_ylrM0HAhKv7TYg4euFZFRFgYJqDOBM7lgNteZ1Ar1OFjL2PbQ9vj_OnuOKfWQvZ85qKIHlzbU_abgNVtj40zq4AYtjVhZsCMD0TtpRPWhcW4wFR-Idb0s_WrHIJmbH77NBgs0Rjk-ETzE11itPPP8SH1tvvtHdE260ne1sa_h0RMJCQ
# 0 Everything Goes On - Porter Robinson - 3WBRfkOozHEsG0hbrBzwlm
# 1 HEARTBREAKER CLUB - City Girl - 6Rpk7fmD3TWTBfJnIpjiZp
# 2 Loved By U - TOKiMONSTA - 1SldN7GTd0ADTjspv96wCl
# 3 Doorman - slowthai - 6bTAz3pg5ywBeZHCQoleJB
# ...

# %% [markdown]
# # Junk code to be deleted eventually lol

# %%
if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("Whoops, need a username!")
    print("usage: python user_playlists.py [username]")
    sys.exit()

playlists = sp.user_playlists(username)

for playlist in playlists['items']:
    print(playlist['name'])

# %%
# 2021 has NoneType of raudio features: sp.audio_features('0qM0FYeAgpZaWhuiGgSioF')
dict_list=[]
count = 0
for track in track_df['track_id']:
    dict_list.append(sp.audio_features(track.strip())[0])
    try:
        audio_feat_df = pd.DataFrame(dict_list)  
    except AttributeError:
        print(f'Track ID: {track} has no audio features')
        count += 1
        pass
        
print(f'{count} songs missing audio features')
audio_feat_df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [41], in <cell line: 4>()
#       3 count = 0
#       4 for track in track_df['track_id']:
# ----> 5     dict_list.append(sp.audio_features(track.strip())[0])
#       6     try:
#       7         audio_feat_df = pd.DataFrame(dict_list)
#
# File ~\anaconda3\lib\site-packages\spotipy\client.py:1680, in Spotify.audio_features(self, tracks)
#    1678 if isinstance(tracks, str):
#    1679     trackid = self._get_id("track", tracks)
# -> 1680     results = self._get("audio-features/?ids=" + trackid)
#    1681 else:
#    1682     tlist = [self._get_id("track", t) for t in tracks]
#
# File ~\anaconda3\lib\site-packages\spotipy\client.py:297, in Spotify._get(self, url, args, payload, **kwargs)
#     294 if args:
#     295     kwargs.update(args)
# --> 297 return self._internal_call("GET", url, payload, kwargs)
#
# ...

# %%
dict_list2=[]
for track in track_df['track_id']:
    dict_list2.append(sp.audio_features(track))
audio_feat_df2 = pd.DataFrame(dict_list2)
audio_feat_df2
# Out:
#                                                      0
# 0    {'danceability': 0.768, 'energy': 0.714, 'key'...
# 1    {'danceability': 0.887, 'energy': 0.633, 'key'...
# 2    {'danceability': 0.505, 'energy': 0.657, 'key'...
# 3    {'danceability': 0.645, 'energy': 0.809, 'key'...
# 4    {'danceability': 0.849, 'energy': 0.424, 'key'...
# ..                                                 ...
# 995  {'danceability': 0.481, 'energy': 0.939, 'key'...
# 996  {'danceability': 0.498, 'energy': 0.987, 'key'...
# 997  {'danceability': 0.441, 'energy': 0.965, 'key'...
# 998  {'danceability': 0.39, 'energy': 0.918, 'key':...
# 999  {'danceability': 0.465, 'energy': 0.964, 'key'...
#
# [1000 rows x 1 columns]

# %% [markdown]
# # 2021 has NoneType of raudio features: sp.audio_features('0qM0FYeAgpZaWhuiGgSioF')
# dict_list=[]
#
# try:
#     for track in track_df['track_id']:
#         if sp.audio_features(track) == None:
#             f[35] = {'danceability': np.nan, 'energy': np.nan, 'key': np.nan, 'loudness': np.nan, 'mode': np.nan, 'speechiness': np.nan, 'acousticness': np.nan, 'instrumentalness': np.nan, 'liveness': np.nan, 'valence': np.nan, 'tempo': np.nan, 'type': np.nan, 'id': np.nan, 'uri': np.nan, 'track_href': np.nan, 'analysis_url': np.nan, 'duration_ms': np.nan, 'time_signature': np.nan}
#             dict_list.append(sp.audio_features(track)[0])
#         else:
#             dict_list.append(sp.audio_features(track)[0])
#     audio_feat_df = pd.DataFrame(dict_list)
# except AttributeError:
#         print(f'Track ID: {track} has no audio features')
# audio_feat_df

# %%
# 2021 has NoneType of raudio features: sp.audio_features('0qM0FYeAgpZaWhuiGgSioF')
dict_list=[]

try:
    for track in track_df['track_id']:
        dict_list.append(sp.audio_features(track)[0])
    audio_feat_df = pd.DataFrame(dict_list)  
except AttributeError:
        print(f'Track ID: {track} has no audio features')
audio_feat_df
# Out:
# Track ID: 7F9aDyXyIqntDtuAAjhZcV has no audio features
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.768  0.7140   10    -5.110     1       0.0401      0.352000
# 1          0.887  0.6330    8   -10.453     1       0.0660      0.062900
# 2          0.505  0.6570   11    -5.240     0       0.0318      0.373000
# 3          0.645  0.8090   11    -6.120     1       0.0385      0.009210
# 4          0.849  0.4240    5    -9.579     0       0.3240      0.063500
# 5          0.717  0.7920    0    -2.703     1       0.0393      0.199000
# 6          0.539  0.5080   10    -6.050     1       0.0288      0.727000
# 7          0.622  0.9190   11    -4.088     1       0.0651      0.016300
# 8          0.824  0.7640    5    -4.175     0       0.0854      0.088800
# 9          0.459  0.6930    0   -10.440     1       0.2540      0.238000
# 10         0.563  0.6640    9    -5.044     1       0.1540      0.335000
# ...

# %%
f = audio_feat_df2[0]
print(f[35])
f[35] = {'danceability': np.nan, 'energy': np.nan, 'key': np.nan, 'loudness': np.nan, 'mode': np.nan, 'speechiness': np.nan, 'acousticness': np.nan, 'instrumentalness': np.nan, 'liveness': np.nan, 'valence': np.nan, 'tempo': np.nan, 'type': np.nan, 'id': np.nan, 'uri': np.nan, 'track_href': np.nan, 'analysis_url': np.nan, 'duration_ms': np.nan, 'time_signature': np.nan}
print(f[35])
print(f[36])
# Out:
# None
# {'danceability': nan, 'energy': nan, 'key': nan, 'loudness': nan, 'mode': nan, 'speechiness': nan, 'acousticness': nan, 'instrumentalness': nan, 'liveness': nan, 'valence': nan, 'tempo': nan, 'type': nan, 'id': nan, 'uri': nan, 'track_href': nan, 'analysis_url': nan, 'duration_ms': nan, 'time_signature': nan}
# {'danceability': 0.345, 'energy': 0.941, 'key': 9, 'loudness': -9.918, 'mode': 1, 'speechiness': 0.0466, 'acousticness': 3.84e-05, 'instrumentalness': 0.633, 'liveness': 0.0511, 'valence': 0.407, 'tempo': 179.626, 'type': 'audio_features', 'id': '7EkWXAI1wn8Ii883ecd9xr', 'uri': 'spotify:track:7EkWXAI1wn8Ii883ecd9xr', 'track_href': 'https://api.spotify.com/v1/tracks/7EkWXAI1wn8Ii883ecd9xr', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7EkWXAI1wn8Ii883ecd9xr', 'duration_ms': 147062, 'time_signature': 4}

# %%
track_df.head(36)
# Out:
#                          artist_name  \
# 0                        Nicky Youre
# 1                          Dj Biffen
# 2                      Morgan Wallen
# 3   Elvis Costello & The Attractions
# 4                              Drake
# 5                           Jay Sean
# 6                    Stephen Sanchez
# 7                     Jonas Brothers
# 8                           Doja Cat
# 9                           Amaranta
# 10                    Olivia Rodrigo
# 11  Elvis Costello & The Attractions
# 12                             Drake
# 13                      Hop hip show
# 14                    Olivia Rodrigo
# 15                        Izaya Tiji
# 16                     Billie Eilish
# 17                          Amaranta
# 18                    Olivia Rodrigo
# 19  Elvis Costello & The Attractions
# 20                         Lil Nas X
# 21                          yt music
# 22                     Justin Bieber
# 23                      Yomille Omar
# ...

# %%
track_df
# Out:
#                           artist_name  \
# 0                         Nicky Youre
# 1                           Dj Biffen
# 2                       Morgan Wallen
# 3    Elvis Costello & The Attractions
# 4                               Drake
# ..                                ...
# 995                        Mark Sixma
# 996                            Kryder
# 997                     Ferry Corsten
# 998                     Nitrous Oxide
# 999                             Omnia
#
#                                             track_name  \
# 0                                              Sunroof
# 1    Merry Christmas and Happy New Year 2021 - Radi...
# 2                                        Wasted On You
# 3                           Pump It Up - 2021 Remaster
# 4          Knife Talk (with 21 Savage ft. Project Pat)
# ..                                                 ...
# 995                              Elemental (FYHYM2021)
# ...

# %%
# personal account info
print(sp.me())
# Out:
# {'display_name': 'sbhewitt91', 'external_urls': {'spotify': 'https://open.spotify.com/user/sbhewitt91'}, 'followers': {'href': None, 'total': 2}, 'href': 'https://api.spotify.com/v1/users/sbhewitt91', 'id': 'sbhewitt91', 'images': [], 'type': 'user', 'uri': 'spotify:user:sbhewitt91'}

# %%
# client credentials flow
search_str = 'weezer'
result = sp.search(search_str)
print(result)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=weezer&type=track&offset=0&limit=10', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3jOstUTkEu2JkjvRdBA5Gu'}, 'href': 'https://api.spotify.com/v1/artists/3jOstUTkEu2JkjvRdBA5Gu', 'id': '3jOstUTkEu2JkjvRdBA5Gu', 'name': 'Weezer', 'type': 'artist', 'uri': 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GD', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI',
# ...

# %%
# audio features
sp.trace = True

if len(sys.argv) > 1:
    tids = sys.argv[1:]
    print(tids)

    start = time.time()
    features = sp.audio_features(tids)
    delta = time.time() - start
    print(json.dumps(features, indent=4))
    print("features retrieved in %.2f seconds" % (delta,))
# Out:
# ['-f', 'C:\\Users\\sbhew\\AppData\\Roaming\\jupyter\\runtime\\kernel-f01465dd-5c54-464e-b06a-191233a482dd.json']
# [
#     null,
#     null
# ]
# features retrieved in 0.07 seconds

# %%
# audio analysis
if len(sys.argv) > 1:
    tid = sys.argv[1]
else:
    tid = 'spotify:track:6EnHdhpdycjPxayoU5VAU9'

start = time.time()
analysis = sp.audio_analysis(tid)
delta = time.time() - start
print(json.dumps(analysis, indent=4))
print("analysis retrieved in %.2f seconds" % (delta,))
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-analysis/-f with Params: {} returned 400 due to invalid request
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\spotipy\client.py:245, in Spotify._internal_call(self, method, url, payload, params)
#     240 response = self._session.request(
#     241     method, url, headers=headers, proxies=self.proxies,
#     242     timeout=self.requests_timeout, **args
#     243 )
# --> 245 response.raise_for_status()
#     246 results = response.json()
#
# File ~\anaconda3\lib\site-packages\requests\models.py:960, in Response.raise_for_status(self)
#     959 if http_error_msg:
# --> 960     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.spotify.com/v1/audio-analysis/-f
#
# ...

# %%
twice_uri = 'spotify:artist:7n2Ycct7Beij7Dj7meI4X0'

results = sp.artist_albums(twice_uri, album_type='album')
albums = results['items']
while results['next']:
    results = sp.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Celebrate
# Formula of Love: O+T=<3
# Perfect World
# Eyes Wide Open
# MORE & MORE
# &TWICE (Repackage)
# &TWICE
# Feel Special
# BDZ (Repackage)
# The year of "YES"
# YES or YES
# BDZ
# Summer Nights
# Merry & Happy
# Twicetagram
# Twicecoaster: Lane 2
# Twicecoaster: Lane 1

# %%
# song previews
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
results = spotify.artist_top_tracks(twice_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : The Feels
# audio    : https://p.scdn.co/mp3-preview/6c85210d5bf3c056b49e2a6ce06abcc2a99d23fe?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b273c11578f0d39a2d639a92046d
#
# track    : I CAN'T STOP ME
# audio    : https://p.scdn.co/mp3-preview/d42dc55267423e80fbf8bffc1aaea7f04210486e?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b273dfb3ec8a83a71cd5bbc595e6
#
# track    : FANCY
# audio    : https://p.scdn.co/mp3-preview/3c733514a1ae8b4960ce1cca282fe922b9376b1b?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b273d0a0974a3a74ad0771a1f87d
#
# track    : What is Love
# audio    : https://p.scdn.co/mp3-preview/4896f7384033b08c79fc13e9ab236f249cb6de33?cid=0f298608fe46432daff4e6304d5607bd
# cover art: https://i.scdn.co/image/ab67616d0000b273d610ab817a71b377cbe54742
#
# track    : Celebrate
# ...

# %%
logger = logging.getLogger('examples.artist_albums')
logging.basicConfig(level='INFO')


def get_args():
    parser = argparse.ArgumentParser(description='Gets albums from artist')
    parser.add_argument('-a', '--artist', required=True,
                        help='Name of Artist')
    return parser.parse_args()


def get_artist(name):
    results = sp.search(q='artist:' + name, type='artist')
    items = results['artists']['items']
    if len(items) > 0:
        return items[0]
    else:
        return None


def show_artist_albums(artist):
    albums = []
    results = sp.artist_albums(artist['id'], album_type='album')
    albums.extend(results['items'])
    while results['next']:
        results = sp.next(results)
        albums.extend(results['items'])
    seen = set()  # to avoid dups
    albums.sort(key=lambda album: album['name'].lower())
    for album in albums:
        name = album['name']
        if name not in seen:
            logger.info('ALBUM: %s', name)
            seen.add(name)


def main():
    args = get_args()
    artist = get_artist(args.artist)
    if artist:
        show_artist_albums(artist)
    else:
        logger.error("Can't find artist: %s", artist)


if __name__ == '__main__':
    main()
# Out:
# usage: ipykernel_launcher.py [-h] -a ARTIST
# ipykernel_launcher.py: error: the following arguments are required: -a/--artist
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    username = 'sbhewitt91'

sp.trace = True
user = sp.user(username)
pprint.pprint(user)
# Out:
# {'display_name': '-f',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/-f'},
#  'followers': {'href': None, 'total': 0},
#  'href': 'https://api.spotify.com/v1/users/-f',
#  'id': '-f',
#  'images': [],
#  'type': 'user',
#  'uri': 'spotify:user:-f'}

# %%
sp = spotipy.Spotify(auth_manager = spotipy.SpotifyOAuth(client_id = cid, client_secret = secret,
                            redirect_uri = "http://localhost:8888/callback",
                            scope = "user-top-read",
                            open_browser=False))


result = sp.track('2BcMwX1MPV6ZHP4tUT9uq6')

# %%
def get_playlists_by_genre(genre, limit):
    results = sp.search(genre, limit=limit, type='playlist')
    return results['playlists']['items']

def print_playlist_info(playlists):
    for playlist in playlists:
        p_name = playlist['name']
        p_id = playlist['id']
        p_tot_tracks = playlist['tracks']['total']
        print(f'{p_name} (Playlist ID:{p_id}) : {p_tot_tracks} tracks')

playlists = get_playlists_by_genre('twice', 50)
print_playlist_info(playlists)
# Out:
# Twice’s Hits (Playlist ID:5hKka3qQ75mbCxJ6KMi3CY) : 19 tracks
# This Is TWICE (Playlist ID:37i9dQZF1DWYlCv3D85m6m) : 85 tracks
# TWICE 4TH WORLD TOUR 'Ⅲ' (Playlist ID:3iA20ztniCf3PDFwGpwWAV) : 28 tracks
# TWICE ヒット曲　日本語 (Playlist ID:0D9pC3xgPRv7H0aMO4W4xj) : 24 tracks
# TWICE PLAYLIST (Playlist ID:76RWDGDuVlpsmpaVZyTeMS) : 56 tracks
# TWICE 4TH WORLD TOUR ‘III’ (Playlist ID:2jR4xDfdvHPUhLTOxNkiIX) : 36 tracks
# TWICE Complete Collection (Playlist ID:4OSKpxBbXwUfxgoSdZJpVx) : 234 tracks
# TWICE 🍭All Songs (Playlist ID:2FQUzy8GOaaXOuCAanx0nO) : 156 tracks
# TWICE Radio (Playlist ID:37i9dQZF1E4s6KXygylRFz) : 50 tracks
# TWICE 全曲 (Playlist ID:1YCC5OGBoc96JyyanJXHKw) : 178 tracks
# Twice Title Tracks (Playlist ID:0C0ZW38xk27fYu0PCjc0US) : 31 tracks
# Talk That Talk - TWICE (Playlist ID:3XYumkwD1HSSKidDMSyXu7) : 143 tracks
# TWICE 4TH WORLD TOUR ‘III’ US (Playlist ID:0KPXcvBbA4pz8LwXMZVz7l) : 47 tracks
# TWICE🌸 (Playlist ID:2QYfS0c0gOvybaKuBzNbRn) : 200 tracks
# ...

# %%
def get_user_playlist_tracks(username,playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
get_user_playlist_tracks('sbhewitt91', '0GoQedvZwO4jaWgtdZXOEs')
# Out:
# [{'added_at': '2019-06-27T05:25:28Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/gabirpontius'},
#    'href': 'https://api.spotify.com/v1/users/gabirpontius',
#    'id': 'gabirpontius',
#    'type': 'user',
#    'uri': 'spotify:user:gabirpontius'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28j8lBWDdDSHSSt5oPlsX2'},
#       'href': 'https://api.spotify.com/v1/artists/28j8lBWDdDSHSSt5oPlsX2',
#       'id': '28j8lBWDdDSHSSt5oPlsX2',
#       'name': 'ZHU',
#       'type': 'artist',
#       'uri': 'spotify:artist:28j8lBWDdDSHSSt5oPlsX2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
# ...

# %%
playlist_tracks = sp.playlist_tracks('3iA20ztniCf3PDFwGpwWAV')
p_artist_name = playlist_tracks['items'][0]['track']['artists'][0]['name']
p_track_name = playlist_tracks['items'][0]['track']['name']
p_track_id = playlist_tracks['items'][0]['track']['id']
print(f'Artist Name: {p_artist_name}')
print(f'Track Name: {p_track_name}')
print(f'Track Id: {p_track_id}')
# Out:
# Artist Name: TWICE
# Track Name: The Feels
# Track Id: 0CNjxPhDov79ceeTqm37HW

# %%
playlist_tracks['items'][0]['track']['name']
# Out:
# 'The Feels'

# %%
def get_playlist_tracks(playlist_id):
    i=0
    track_list = []
    results = sp.playlist_tracks(playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'][i]['track']['id'])
        track_list.append(results['items'][i]['track']['id'])
        i+=1
    return tracks #track_list

# %%
get_playlist_tracks('3iA20ztniCf3PDFwGpwWAV')
# Out:
# [{'added_at': '2022-02-16T06:57:46Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/bf1wkl4bbo9oqeru3u5qefpoz'},
#    'href': 'https://api.spotify.com/v1/users/bf1wkl4bbo9oqeru3u5qefpoz',
#    'id': 'bf1wkl4bbo9oqeru3u5qefpoz',
#    'type': 'user',
#    'uri': 'spotify:user:bf1wkl4bbo9oqeru3u5qefpoz'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2Ycct7Beij7Dj7meI4X0'},
#       'href': 'https://api.spotify.com/v1/artists/7n2Ycct7Beij7Dj7meI4X0',
#       'id': '7n2Ycct7Beij7Dj7meI4X0',
#       'name': 'TWICE',
#       'type': 'artist',
#       'uri': 'spotify:artist:7n2Ycct7Beij7Dj7meI4X0'}],
#     'available_markets': ['KR'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ZxEVmqxfl3xNwtb0zvBaE'},
#     'href': 'https://api.spotify.com/v1/albums/5ZxEVmqxfl3xNwtb0zvBaE',
# ...

# %%
def get_playlists_by_genre(genre, limit):
    results = sp.search(genre, limit=limit, type='playlist')
    return results['playlists']['items']

def print_playlist_info(playlists):
    for playlist in playlists:
        p_name = playlist['name']
        p_id = playlist['id']
        p_tot_tracks = playlist['tracks']['total']
        print(f'{p_name} (Playlist ID:{p_id}) : {p_tot_tracks} tracks')

playlists = get_playlists_by_genre('twice', 10)
print_playlist_info(playlists)

#def get_playlist_tracks(playlist_id):
#    i=0
#    results = sp.playlist_tracks(playlist_id)
#    tracks = results['items'][i]['track']['id']
#    while results['next']:
#        results = sp.next(results)
#        tracks.extend(results['items'][i]['track']['id'])
#        i+=1
#    return tracks
# Out:
# Twice’s Hits (Playlist ID:5hKka3qQ75mbCxJ6KMi3CY) : 19 tracks
# This Is TWICE (Playlist ID:37i9dQZF1DWYlCv3D85m6m) : 85 tracks
# TWICE 4TH WORLD TOUR 'Ⅲ' (Playlist ID:3iA20ztniCf3PDFwGpwWAV) : 28 tracks
# TWICE ヒット曲　日本語 (Playlist ID:0D9pC3xgPRv7H0aMO4W4xj) : 24 tracks
# TWICE PLAYLIST (Playlist ID:76RWDGDuVlpsmpaVZyTeMS) : 56 tracks
# TWICE 4TH WORLD TOUR ‘III’ (Playlist ID:2jR4xDfdvHPUhLTOxNkiIX) : 36 tracks
# TWICE Complete Collection (Playlist ID:4OSKpxBbXwUfxgoSdZJpVx) : 234 tracks
# TWICE 🍭All Songs (Playlist ID:2FQUzy8GOaaXOuCAanx0nO) : 156 tracks
# TWICE Radio (Playlist ID:37i9dQZF1E4s6KXygylRFz) : 50 tracks
# TWICE 全曲 (Playlist ID:1YCC5OGBoc96JyyanJXHKw) : 178 tracks
