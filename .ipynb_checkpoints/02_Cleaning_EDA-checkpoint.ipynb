# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
df_2012 = pd.read_csv('./data/tracks_2012.csv')

# %%
df_2012
# Out:
#               artist_name                                  track_name  \
# 0             Frank Ocean                                        Lost
# 1             David Bowie                  Five Years - 2012 Remaster
# 2          Kendrick Lamar                                 Money Trees
# 3    Electro Dark Project                                   Year 2012
# 4              Chief Keef                                   Love Sosa
# ..                    ...                                         ...
# 954     Dance Dance Music                          Titanium (Remixed)
# 955              Labrinth  Beneath Your Beautiful (feat. Emeli Sandé)
# 956     Johann Strauss II             Tik-Tak, Polka schnell, Op. 365
# 957          Stick Figure                                     Breathe
# 958              Evacuate                                        2012
#
#                    track_id  popularity  danceability  energy  key  loudness  \
# ...

# %%
# dynamic variable naming
years = [2012, 2013, 2014, 2015, 2019, 2020, 2021]
for year in years:
    globals()[f'df_{year}'] = pd.read_csv(f'./data/tracks_{year}.csv')

# %%
df_2013
# Out:
#                artist_name                                         track_name  \
# 0        The Neighbourhood                                    Sweater Weather
# 1                Riff Raff                            Rookie of the Year 2013
# 2                     MKTO                                            Classic
# 3               Kanye West                                            Bound 2
# 4                   Eagles     Please Come Home for Christmas - 2013 Remaster
# ..                     ...                                                ...
# 965       Armin van Buuren                                         Nehalennia
# 966  Johann Sebastian Bach  Das Wohltemperierte Klavier: Book 1, BWV 846-8...
# 967                 Maejor                                              Lolly
# 968             The Pogues                           Cotton Fields - 2013 Mix
# 969  Johann Sebastian Bach       French Suite No. 5 in G, BWV 816: 4. Gavotte
#
# ...

# %%
frames = [df_2012, df_2013, df_2014, df_2015, df_2019, df_2020, df_2021]
merged_df = pd.concat(frames)
merged_df
# Out:
#               artist_name                                      track_name  \
# 0             Frank Ocean                                            Lost
# 1             David Bowie                      Five Years - 2012 Remaster
# 2          Kendrick Lamar                                     Money Trees
# 3    Electro Dark Project                                       Year 2012
# 4              Chief Keef                                       Love Sosa
# ..                    ...                                             ...
# 962                  K120  It's Christmas, You Are 13 Years Old and Happy
# 963                 Nic D                                        Icee Pop
# 964                   Zen                                       Year 3000
# 965               JELEEL!                                        DIVE IN!
# 966            Matt Monro                  Spanish Eyes - Remastered 2021
#
#                    track_id  popularity  danceability  energy  key  loudness  \
# ...

# %%
merged_df = merged_df.drop_duplicates()
merged_df.drop(columns = ['type', 'id', 'uri', 'track_href', 'analysis_url'], inplace = True)
merged_df
# Out:
#               artist_name                                      track_name  \
# 0             Frank Ocean                                            Lost
# 1             David Bowie                      Five Years - 2012 Remaster
# 2          Kendrick Lamar                                     Money Trees
# 3    Electro Dark Project                                       Year 2012
# 4              Chief Keef                                       Love Sosa
# ..                    ...                                             ...
# 962                  K120  It's Christmas, You Are 13 Years Old and Happy
# 963                 Nic D                                        Icee Pop
# 964                   Zen                                       Year 3000
# 965               JELEEL!                                        DIVE IN!
# 966            Matt Monro                  Spanish Eyes - Remastered 2021
#
#                    track_id  popularity  danceability  energy  key  loudness  \
# ...

# %%
merged_df.to_csv('./data/merged_tracks.csv', index = False)

# %%
# audio feature definitions https://developer.spotify.com/documentation/web-api/reference/#/operations/get-audio-features

# %%
merged_df.columns
# Out:
# Index(['artist_name', 'track_name', 'track_id', 'popularity', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms',
#        'time_signature'],
#       dtype='object')
